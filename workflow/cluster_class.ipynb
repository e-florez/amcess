# %%
# creating the path (PYTHONPATH) to our module.
# assuming that our 'amcess' directory is out ('..') of our current directory 
import os
import sys
module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# importing de Molecule and Cluster class
from amcess.molecule import Molecule
from amcess.cluster import Cluster

# %% [markdown]
# # Building Cluster Object

# %%
water = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
c_1w = Cluster(water)
print(f"Cluster Object Type: {c_1w}")
print(f"Type of elements of Cluste Object: {c_1w.GetClusterDict()[0]}")
print(f"Array of Cluster Object: {c_1w.GetMols()}")
print(f"Coordinates of Cluster Object: {c_1w.GetMol(0).GetMolCoord()}")
print(f"Coordinates of Atom 1: {c_1w.GetMol(0).GetAtom(0).GetCoord()}")
# Out:
# Cluster Object Type: Cluster of (1) molecules and (3) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Type of elements of Cluste Object: 3
# charge: 0 multiplicity: 1
# O     	     0.00000000	     0.00000000	     0.00000000
# H     	     0.58708000	     0.75754000	     0.00000000
# H     	    -0.58708000	     0.75754000	     0.00000000
#
# Array of Cluster Object: [Molecule(_atoms=[('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)]
# Coordinates of Cluster Object: [(0, 0, 0), (0.58708, 0.75754, 0), (-0.58708, 0.75754, 0)]
# Coordinates of Atom 1: (0, 0, 0)

# %%
water = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
c_1w = Cluster(water)
c_1w
# Out:
# Cluster(_atoms=[('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
water1 = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
water2 = [("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 1), ("H", -0.58708 + 2.5, 0.75754, 0)]
c_2w = Cluster(water1, water2)
c_2w
# Out:
# Cluster(_atoms=[('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0), ('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 1), ('H', 1.91292, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
water = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
c_3w = Cluster(3 * water)
c_3w
# Out:
# Cluster(_atoms=[('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0), ('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0), ('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
c_3w = Cluster(water + water + water)
c_3w
# Out:
# Cluster(_atoms=[('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0), ('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0), ('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
water = {"atoms":[("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)] }
c_1w = Cluster(water)
c_1w
# Out:
# Cluster(_atoms=[('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = {"atoms":[("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)] }
w2 = {"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 1), ("H", -0.58708 + 2.5, 0.75754, 0)]}
c_2w = Cluster(w1,w2)
c_2w
# Out:
# Cluster(_atoms=[('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0), ('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 1), ('H', 1.91292, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
w2 = {"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 1), ("H", -0.58708 + 2.5, 0.75754, 0)]}
c_2w = Cluster(w1,w2)
c_2w
# Out:
# Cluster(_atoms=[('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0), ('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 1), ('H', 1.91292, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
water = Molecule({"atoms":[("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]})
c_1w = Cluster(water)
c_1w
# Out:
# Cluster(_atoms=[('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = Molecule([("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)])
w2 = Molecule({"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]})
c_2w = Cluster(w1,w2)
c_2w
# Out:
# Cluster(_atoms=[('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0), ('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 0), ('H', 1.91292, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = Molecule([("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)])
w2 = Molecule({"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]})
c_2w = Cluster(w1+w2)
c_2w
# Out:
# Cluster(_atoms=[('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0), ('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 0), ('H', 1.91292, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = Molecule([("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)])
w2 = {"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]}
w3 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
c_3w = Cluster(w1,w2,w3)
c_3w
# Out:
# Cluster(_atoms=[('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0), ('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 0), ('H', 1.91292, 0.75754, 0), ('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = Molecule({"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]})
w2 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
c_2w = Cluster(w1+Molecule(w2))
c_2w
# Out:
# Cluster(_atoms=[('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 0), ('H', 1.91292, 0.75754, 0), ('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = Molecule({"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]})
w2 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
c_2w = Cluster(w1+Molecule(w2))
dimer = Cluster(c_2w)
dimer
# Out:
# Cluster(_atoms=[('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 0), ('H', 1.91292, 0.75754, 0), ('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = Molecule({"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]})
w2 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
w3 = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
c_3w = Cluster(w1+Molecule(w2),w3)
trimer = Cluster(c_3w)
trimer
# Out:
# Cluster(_atoms=[('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 0), ('H', 1.91292, 0.75754, 0), ('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0), ('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %% [markdown]
# # Check Methods Now
# Vale la pena tener Get y Set cuando las variables ya son atributos del objeto, como pasa con _seed, _sphere_ceter, ...

# %%
w1 = Molecule({"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]})
w2 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
c_2w = Cluster(w1,Molecule(w2))
print(f"Dictionary print:\n {c_2w.GetClusterDict()}")
print(f"Freeze molecule: {c_2w.GetFreezeMol()}  {c_2w._freeze_molecule}")
c_2w.SetFreezeMol(2)
print(f"Freeze molecule: {c_2w.GetFreezeMol()}  {c_2w._freeze_molecule}")
c_2w.SetSeed(9212)
print(f"Random Generator: {c_2w.GetRandomGen()}")
print(f"Sphere Center: {c_2w.GetSphereCenter()}")
c_2w.SetSphereR(3.)
print(f"Sphere Radios: {c_2w.GetSphereR()}")
print(f"Total Molecules: {c_2w.GetTotalMol()}")
# Out:
# Dictionary print:
#  {0: Molecule(_atoms={'atoms': [('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 0), ('H', 1.91292, 0.75754, 0)]}, _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False), 1: Molecule(_atoms=[('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)}
# Freeze molecule: []  []
# Freeze molecule: [2]  [2]
# Random Generator: Generator(PCG64)
# Sphere Center: (0.0, 0.0, 0.0)
# Sphere Radios: 3.0
# Total Molecules: 2

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(f"Molecule 1: \n{dimer.GetMol(0)}")
print(f"Molecule 2: \n{dimer.GetMol(1)}")
dimer
# Out:
# Molecule 1:
# 3
# charge: 0 multiplicity: 1
# O     	    -2.50000000	     0.00000000	     0.00000000
# H     	    -1.91292000	     0.75754000	     0.00000000
# H     	    -3.08708000	     0.75754000	     0.00000000
#
# Molecule 2:
# 3
# charge: 0 multiplicity: 1
# O     	    -2.50000000	     0.00000000	     0.00000000
# H     	    -1.91292000	     0.75754000	     0.00000000
# H     	    -3.08708000	     0.75754000	     0.00000000
# Cluster(_atoms=[('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0), ('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print("Molecules are overlapping: "
      f"{dimer.Overlapping(dimer.GetClusterDict()[0].GetMolCoord(),dimer.GetClusterDict()[1].GetMolCoord())}"
      )
print(f"Molecule 1: \n{dimer.GetClusterDict()[0]}")
print(f"Molecule 2: \n{dimer.GetClusterDict()[1]}")
dimer
# Out:
# Molecules are overlapping: True
# Molecule 1:
# 3
# charge: 0 multiplicity: 1
# O     	    -2.50000000	     0.00000000	     0.00000000
# H     	    -1.91292000	     0.75754000	     0.00000000
# H     	    -3.08708000	     0.75754000	     0.00000000
#
# Molecule 2:
# 3
# charge: 0 multiplicity: 1
# O     	    -2.50000000	     0.00000000	     0.00000000
# H     	    -1.91292000	     0.75754000	     0.00000000
# H     	    -3.08708000	     0.75754000	     0.00000000
# Cluster(_atoms=[('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0), ('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(dimer)
dimer = dimer.TranslateMol(0, x = 1)
print(dimer)
dimer
# Out:
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -1.5, 0.0, 0.0), ('H', -0.91292, 0.7575399999999999, 0.0), ('H', -2.0870800000000003, 0.7575399999999999, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
# ...

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(dimer)
dimer = dimer.TranslateMol(0, x = 2)
#! Why rotate asks by coordinates instead by angle
dimer = dimer.RotateMol(0,0,0,90)
print(dimer)
dimer
# Out:
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -0.5847738351373855, 0.08477383513738548, 0.0), ('H', 0.17276616486261454, -0.5023061648626145, 0.0), ('H', 0.1727661648626143, 0.6718538351373858, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
# ...

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(dimer)
dimer = dimer.RemoveMol(1)
print(dimer)
dimer
# Out:
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (1) molecules and (3) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
# Cluster(_atoms=[('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
trimer = Cluster(w,w,w)
print(trimer)
trimer = trimer.RemoveMol(1)
print(trimer)
trimer
# Out:
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
# ...

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(dimer)
dimer = dimer.InitializeCluster()
print(dimer)
dimer
# Out:
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.7575399999999999, 0.0), ('H', -3.0870800000000003, 0.7575399999999999, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.374046862264434, 0.3899510767548522, 1.4781164148538142), ('H', -2.2520945003289055, 1.3405315236550126, 1.48547938907876), ('H', -3.134919041887702, 0.7249919686391275, 1.954929695961552)]
#      --> charge: +0
#      --> multiplicity: 1
# ...

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
trimer = Cluster(w,w,w)
print(trimer)
trimer = trimer.InitializeCluster()
print(trimer)
trimer
# Out:
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.7575399999999999, 0.0), ('H', -3.0870800000000003, 0.7575399999999999, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
# ...

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(dimer)
dimer = dimer.MoveMol(1)
print(dimer)
dimer
# Out:
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.896024271020423, 0.24994637286469046, 1.5139163182877304), ('H', -2.492108393421626, 1.112018987816115, 1.4034059188928958), ('H', -3.6367545764632885, 0.8510461912589309, 1.4215723909024902)]
#      --> charge: +0
#      --> multiplicity: 1
# ...

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
trimer = Cluster(w,w,w)
print(trimer)
trimer = trimer.MoveMol(1)
print(trimer)
trimer
# Out:
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
# ...

# %%
#! Warning: dimer.CalCentRSphere doesn't update only, it's neccesary dimer = dimer.CalCentRSphere()
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(dimer)
print(f"Radio: {dimer.GetSphereR()} Center: {dimer.GetSphereCenter()}\n")
dimer = dimer.CalCentRSphere()
print(dimer)
print(f"Radio: {dimer.GetSphereR()} Center: {dimer.GetSphereCenter()}")
dimer
# Out:
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Radio: None Center: (0.0, 0.0, 0.0)
#
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.7575399999999999, 0.0), ('H', -3.0870800000000003, 0.7575399999999999, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -3.492926011501312, -0.32415505617599627, 1.1434352401589745), ('H', -3.2126009343322512, 0.5904261750761244, 1.0843691707831045), ('H', -4.268303634261379, 0.14386824589006614, 0.829949181703215)]
#      --> charge: +0
# ...

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
trimer = Cluster(w,w,w)
print(trimer)
print(f"Radio: {trimer.GetSphereR()} Center: {trimer.GetSphereCenter()}\n")
trimer = trimer.CalCentRSphere()
print(trimer)
print(f"Radio: {trimer.GetSphereR()} Center: {trimer.GetSphereCenter()}")
trimer
# Out:
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Radio: None Center: (0.0, 0.0, 0.0)
#
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.7575399999999999, 0.0), ('H', -3.0870800000000003, 0.7575399999999999, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
# ...

# %% [markdown]
# # Check Magic Method

# %%
# Decopy produce conflict
w1 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
w2 = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
c = Cluster(w1)
c += w2
print(f"Total Molecules: {c}")
# Out:
# Total Molecules: Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1

# %%
# Decopy produce conflict
w1 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
w2 = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
c = Cluster(w1)
c1 = c + w2
print(f"Total Molecules: {c1}")
# Out:
# Total Molecules: Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1

# %%
w1 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
c = Cluster(w1)
c += c
print(f"Total Molecules: {c}")
# Out:
# Total Molecules: Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1

# %%
w1 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
w2 = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
c = Cluster(w1)
d = Cluster(w2)
e = c + d
print(f"Total Molecules: {e}")
if isinstance(d, Molecule):
    print("Cluster(w2) is instance of Molecule class")
# Out:
# Total Molecules: Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster(w2) is instance of Molecule class

# %%
# Decopy produce conflict
w1 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
c = Cluster(w1)
c *= 3
print(f"Total Molecules: {c}")
# Out:
# Total Molecules: Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)]
#      --> charge: +0
#      --> multiplicity: 1

# %% [markdown]
# # Check Molecule's Methos in Cluster Object

# %%
w1 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
w2 = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
w3 = [("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]
trimer = Cluster(w1,w3)
trimer += w2
print(f"Type of class: {type(trimer)}")
print(f"Number of Atoms: {trimer.GetNumAtoms()}")
print(f"Atomic symbols: {trimer.GetAtomicSymbols()}")
print(f"Atomic Number: {trimer.GetAtomicNumbers()}")
print(f"Atomic coordinates:\n {trimer.GetMolCoord()}")
print(f"Atomic masses: {trimer.GetAtomicMasses()}")
print(f"Molecule mass: {trimer.GetMolMass()}")
print(f"Molecule charge: {trimer.GetMolCharge()}")
print(f"Molecule mutiplicity: {trimer.GetMolMultiplicity()}")
print(f"Print Molecule dictionary:\n {trimer.GetMolDict()}")
print(f"Print Molecule list:\n {trimer.GetMolList()}")
print(f"Center of mass of molecule: {trimer.GetMolCM()}")
print(f"Axes principal of molecule: {trimer.GetMolPrincipalAxes()}")
print(f"Print Atoms for index: {trimer.GetAtom(0)}")
print(trimer)
trimer
# Out:
# Type of class: <class 'amcess.cluster.Cluster'>
# Number of Atoms: 9
# Atomic symbols: ['O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H']
# Atomic Number: [8, 1, 1, 8, 1, 1, 8, 1, 1]
# Atomic coordinates:
#  [(-2.5, 0, 0), (-1.91292, 0.75754, 0), (-3.0870800000000003, 0.75754, 0), (2.5, 0, 0), (3.0870800000000003, 0.75754, 0), (1.91292, 0.75754, 0), (0, 0, 0), (0.58708, 0.75754, 0), (-0.58708, 0.75754, 0)]
# Atomic masses: [15.999, 1.008, 1.008, 15.999, 1.008, 1.008, 15.999, 1.008, 1.008]
# Molecule mass: 54.045000000000016
# Molecule charge: 0
# Molecule mutiplicity: 1
# Print Molecule dictionary:
#  {'atoms': [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0), ('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 0), ('H', 1.91292, 0.75754, 0), ('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)], 'charge': 0, 'multiplicity': 1}
# Print Molecule list:
# ...

# %%
print("Cluster Dict:\n ",trimer.GetClusterDict())
print("Molecule Dict:\n ",trimer.GetMolDict())
print("Cluster List:\n ",trimer.GetClusterList())
print("Molecule List:\n ",trimer.GetMolList())
print("Block XYZ from Molecule Class Method:\n ",trimer.GetBlockXYZ())
# Out:
# Cluster Dict:
#   {0: Molecule(_atoms={'atoms': [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)], 'charge': 0, 'multiplicity': 1}, _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False), 1: Molecule(_atoms={'atoms': [('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 0), ('H', 1.91292, 0.75754, 0)], 'charge': 0, 'multiplicity': 1}, _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False), 2: Molecule(_atoms={'atoms': [('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)], 'charge': 0, 'multiplicity': 1}, _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)}
# Molecule Dict:
#   {'atoms': [('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0), ('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 0), ('H', 1.91292, 0.75754, 0), ('O', 0, 0, 0), ('H', 0.58708, 0.75754, 0), ('H', -0.58708, 0.75754, 0)], 'charge': 0, 'multiplicity': 1}
# ...
