# %% [markdown]
# # Import a Molecules/Atom from cartesian coordinates:
# **Task:**
# 1. Create a Molecule object from its cartesian coordinates
# 2. Ask for its atomic and molecular properties

# %% [markdown]
# ## [Water molecule](https://en.wikipedia.org/wiki/Properties_of_water) ($H_{2}O$):
#
# <img
# src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b7/H2O_2D_labelled.svg/2560px-H2O_2D_labelled.svg.png"
# alt="water"
# width="200"
# height="100"
# />
#
# ### Properties:
# - Number of molecules: 1
# - Number of atoms: 3
# - Atomic symbols: O, H, H
# - Atomic masses [g/mol]:
#     - O: 15.999
#     - H: 1.008
#     - H: 1.008
# - Molar mass [g/mol]: 18.015
# - Cartesian coordinates [Angstrom]:
#     ```XYZ
#     O    0.00000    0.00000    0.00000
#     H    0.58708    0.75754    0.00000
#     H    0.58708   -0.75754    0.00000
#     ```
# - Bond distance [Angstrom]:
#     - H-O: 0.9584 (95.84 pm)
#     - H-H: 1.5151
# - Bond angle [Degrees]:
#     - H-O-H: 104.45
#     - H-H-O: 37.78

# %%
# crating the path (PYTHONPATH) to our module.
# assuming that our 'src' directory is out ('..') of our current directory 
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Import Molecule Class
from src.base_molecule import Molecule

# %%
# Creates a molecule. You can use a list, a dictionary (the key MUST be "atoms")
# or another molecule object (see below)

# 1 Option
water=[("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
water_molecule = Molecule(water)

# 2 Option
water_dict = {"atoms": [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]}
water_molecule = Molecule(water_dict)

# %%
## See initial molecule.

import py3Dmol

water_molecule = Molecule(water_dict)
water_molecule = water_molecule.translate(0, x=1.5, y=1.5, z=1.5)
bi_water = water_molecule.add_fragments(water_dict)


xyz_view = py3Dmol.view(width=300,height=200)
xyz_view.addModel(str(bi_water),'xyz')
xyz_view.setStyle({'stick':{}})
# Out:
# <div id="3dmolviewer_16329225451770737"  style="position: relative; width: 300px; height: 200px">
#         <p id="3dmolwarning_16329225451770737" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16329225451770737 = null;
# var warn = document.getElementById("3dmolwarning_16329225451770737");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16329225451770737 = $3Dmol.createViewer($("#3dmolviewer_16329225451770737"),{backgroundColor:"white"});
# viewer_16329225451770737.zoomTo();
# 	viewer_16329225451770737.addModel("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 1.50000000\t 1.50000000\t 1.50000000\nH\t 2.08708000\t 2.25754000\t 1.50000000\nH\t 0.91292000\t 2.25754000\t 1.50000000\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\n","xyz");
# 	viewer_16329225451770737.setStyle({"stick": {}});
# viewer_16329225451770737.render();
# });
# </script>

# %%
import numpy as np
from scipy.optimize import shgo
from pyscf import gto, scf


def optimization(x):
    """Funcion a optimizar. Primero se introduce la molécula de agua (water_dict), 
    luego, con la clase Molecule la trasladamos una cierta distancia (x=y=z=1.5) y luego
    agregamos el fragmento water_dict, para tener dos moléculas de agua separadas en 1.5 angs en todas direcciones. 

    Luego, a la molécula de 2 aguas, la trasladamos y rotamos en función de x, un 1-D array.
    A esa molécula, le calculanos la energía, siguiendo la base por defecto y RHF.  
    Parameters
    ----------
    x : [1-D Array, de 6 variables, en este caso]
        [variables x,y,z de traslación y los siguientes 3 de rotación]

    Returns
    -------
    []
        [Retorna la energía total del sistema, dado los parámetros en x]
    """
    

    water_molecule = Molecule(water_dict)
    water_molecule = water_molecule.translate(0, x=1.5, y=1.5, z=1.5)
    water_molecule_2 = Molecule(water_dict).translate(0,x=x[0],y=x[1],z=x[2]).rotate(0,x[3],x[4],x[5])
    water_cluster = water_molecule.add_fragments(water_molecule_2)


    mol = gto.Mole()
    #mol.atom = "water.xyz"
    mol.fromstring(str(water_cluster))
    mol.build(basis = 'sto-3g')
    

    mf = scf.RHF(mol)
    mf.kernel()
    
    return mf.energy_tot()

water_dict = {"atoms": [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]}
bounds = [(-1.5,1.5),(-1.5,1.5),(-2.5,2.5),(0,180),(0,90),(0,180)]

#aquí habría que probar con el método sobol, y también con otros métodos de optimización. 
minimos = shgo(optimization, bounds=bounds, sampling_method='simplicial')

print(minimos.xl, minimos.funl)



#Primera vez: demoró 24 minutos.
#Segunda vez: demoró 6 minutos
# Out:
# converged SCF energy = -149.860304492298
# converged SCF energy = -149.862117813477
# converged SCF energy = -149.857916858664
# converged SCF energy = -149.860092788328
# converged SCF energy = -149.859475386412
# converged SCF energy = -149.859164331339
# converged SCF energy = -149.862216656129
# converged SCF energy = -149.861034114762
# converged SCF energy = -149.85981191307
# converged SCF energy = -145.697531356047
# converged SCF energy = -149.85921701341
# converged SCF energy = -149.861538956924
# converged SCF energy = -149.862661785526
# converged SCF energy = -149.818253960676
# converged SCF energy = -149.859432933011
# converged SCF energy = -149.853972163414
# converged SCF energy = -149.86331209502
# converged SCF energy = -149.851149326348
# converged SCF energy = -149.860160374123
# converged SCF energy = -149.842932731143
# converged SCF energy = -149.863541117318
# converged SCF energy = -149.43932153795
# converged SCF energy = -149.838142911286
# converged SCF energy = -149.858878163363
# converged SCF energy = -149.859889866628
# converged SCF energy = -149.862077932288
# converged SCF energy = -149.858027296388
# converged SCF energy = -149.680151857361
# converged SCF energy = -149.860579481006
# converged SCF energy = -148.832330207589
# converged SCF energy = -149.86347986885
# converged SCF energy = -149.860814469091
# converged SCF energy = -149.861261275536
# converged SCF energy = -149.859460560408
# converged SCF energy = -149.863005589508
# converged SCF energy = -149.854166066743
# converged SCF energy = -149.860023402841
# converged SCF energy = -148.464200035473
# converged SCF energy = -149.84640893588
# converged SCF energy = -149.860131640234
# converged SCF energy = -149.862918063983
# converged SCF energy = -149.857310998306
# converged SCF energy = -149.862032575571
# converged SCF energy = -149.8245165039
# converged SCF energy = -149.863558732654
# converged SCF energy = -145.698839236274
# converged SCF energy = -149.862386404987
# converged SCF energy = -149.859769615806
# converged SCF energy = -149.860161744064
# converged SCF energy = -149.29840270393
# converged SCF energy = -149.822107190231
# converged SCF energy = -149.859497575517
# converged SCF energy = -149.857885125349
# converged SCF energy = -149.813758365029
# converged SCF energy = -149.859811463853
# converged SCF energy = -149.861688081298
# converged SCF energy = -149.861435703024
# converged SCF energy = -149.536917972643
# converged SCF energy = -149.854498902949
# converged SCF energy = -149.859261806031
# converged SCF energy = -149.862064378282
# converged SCF energy = -149.860452912561
# converged SCF energy = -149.864695410162
# converged SCF energy = -149.857652394953
# converged SCF energy = -149.861008192497
# converged SCF energy = -149.513426910373
# converged SCF energy = -149.866642315912
# converged SCF energy = -149.859984693611
# converged SCF energy = -149.859661082274
# converged SCF energy = -149.865815478567
# converged SCF energy = -149.860757608206
# converged SCF energy = -149.861120538942
# converged SCF energy = -149.861327119581
# converged SCF energy = -149.433196646719
# converged SCF energy = -149.648153790247
# converged SCF energy = -149.857575795723
# converged SCF energy = -149.859921259628
# converged SCF energy = -149.859277220361
# converged SCF energy = -149.862118062397
# converged SCF energy = -149.862140888356
# converged SCF energy = -149.862420921453
# converged SCF energy = -149.858938733663
# converged SCF energy = -149.86096066404
# converged SCF energy = -149.748863606398
# converged SCF energy = -149.859968463741
# converged SCF energy = -149.108138680124
# converged SCF energy = -149.851940925793
# converged SCF energy = -149.860829689263
# converged SCF energy = -149.859351169767
# converged SCF energy = -149.805917081905
# converged SCF energy = -149.861239930849
# converged SCF energy = -149.829733536338
# converged SCF energy = -149.86136610693
# SCF not converged.
# SCF energy = -140.417818393377
# converged SCF energy = -149.848713792357
# converged SCF energy = -149.860211136545
# converged SCF energy = -149.862000257075
# converged SCF energy = -149.857841044319
# converged SCF energy = -149.860511668184
# converged SCF energy = -149.825011092408
# converged SCF energy = -149.862804464742
# converged SCF energy = -144.607093836225
# converged SCF energy = -149.861178102991
# converged SCF energy = -149.860571075265
# converged SCF energy = -149.863299195661
# converged SCF energy = -149.863474886449
# converged SCF energy = -149.856397176721
# converged SCF energy = -149.802168861637
# converged SCF energy = -149.860182097519
# converged SCF energy = -149.561166447947
# converged SCF energy = -149.852330907392
# converged SCF energy = -149.860549276942
# converged SCF energy = -149.860030725647
# converged SCF energy = -149.052784695171
# converged SCF energy = -149.861633495665
# converged SCF energy = -149.858072724796
# converged SCF energy = -149.861585342038
# converged SCF energy = -149.85887549754
# converged SCF energy = -149.865254050374
# converged SCF energy = -149.850226798901
# converged SCF energy = -149.859999423273
# converged SCF energy = -149.765343069987
# converged SCF energy = -149.843144619654
# converged SCF energy = -149.86241535362
# converged SCF energy = -149.858263254339
# converged SCF energy = -149.861100795627
# converged SCF energy = -149.860238309693
# converged SCF energy = -149.858574476275
# converged SCF energy = -149.861934995672
# converged SCF energy = -149.861701534079
# converged SCF energy = -149.859527017495
# converged SCF energy = -149.865464392405
# converged SCF energy = -149.860877046358
# converged SCF energy = -147.59747754957
# converged SCF energy = -149.816251115454
# converged SCF energy = -149.859597758234
# converged SCF energy = -149.861539668406
# converged SCF energy = -149.860858714013
# converged SCF energy = -149.862017561045
# converged SCF energy = -149.647486056913
# converged SCF energy = -149.862270465516
# converged SCF energy = -145.490938341269
# converged SCF energy = -149.857315166949
# converged SCF energy = -149.86129106939
# converged SCF energy = -149.860203034674
# converged SCF energy = -149.727025744138
# converged SCF energy = -149.648808929462
# converged SCF energy = -149.862113037733
# converged SCF energy = -149.861663603078
# converged SCF energy = -149.859213683531
# converged SCF energy = -149.861690621961
# converged SCF energy = -149.856665178847
# converged SCF energy = -149.859508359396
# converged SCF energy = -147.349647092577
# converged SCF energy = -149.859581827229
# converged SCF energy = -149.859453999517
# converged SCF energy = -149.859778906085
# converged SCF energy = -149.850744327987
# converged SCF energy = -149.862140215194
# converged SCF energy = -149.861918397727
# converged SCF energy = -149.861295836305
# converged SCF energy = -149.72810892122
# converged SCF energy = -149.852491368897
# converged SCF energy = -149.860088307195
# converged SCF energy = -149.86163892838
# converged SCF energy = -149.673041044212
# converged SCF energy = -149.862733847383
# converged SCF energy = -149.851741564047
# converged SCF energy = -149.860494626729
# converged SCF energy = -149.579174525111
# converged SCF energy = -149.86427595643
# converged SCF energy = -149.860753645788
# converged SCF energy = -149.858836225909
# converged SCF energy = -149.862305229214
# converged SCF energy = -149.859891994183
# converged SCF energy = -149.86002449956
# converged SCF energy = -149.862667664332
# converged SCF energy = -149.860036057164
# converged SCF energy = -149.861905231679
# converged SCF energy = -149.834737127086
# converged SCF energy = -149.861589886235
# converged SCF energy = -149.003344229649
# converged SCF energy = -149.857737202452
# converged SCF energy = -149.859760728038
# converged SCF energy = -149.863390151124
# converged SCF energy = -149.852992116902
# converged SCF energy = -149.859664605572
# converged SCF energy = -149.686803216239
# converged SCF energy = -149.858931155349
# converged SCF energy = -148.969532973874
# converged SCF energy = -149.858188539344
# converged SCF energy = -149.860353914997
# converged SCF energy = -149.86222094322
# converged SCF energy = -149.858931657518
# converged SCF energy = -149.858182521819
# converged SCF energy = -149.83258220136
# converged SCF energy = -149.861287049229
# converged SCF energy = -147.618417620444
# converged SCF energy = -149.864294127325
# converged SCF energy = -149.859103276201
# converged SCF energy = -149.866642315912
# converged SCF energy = -149.866642316003
# converged SCF energy = -149.86664231564
# converged SCF energy = -149.866642315903
# converged SCF energy = -149.866642315912
# converged SCF energy = -149.866642315912
# converged SCF energy = -149.866642315912
# converged SCF energy = -149.866773484389
# converged SCF energy = -149.866773484481
# converged SCF energy = -149.866773484629
# converged SCF energy = -149.866773486346
# converged SCF energy = -149.866773484389
# converged SCF energy = -149.866773484389
# converged SCF energy = -149.866773484389
# converged SCF energy = -149.867185168302
# converged SCF energy = -149.867214786029
# converged SCF energy = -149.867214786041
# converged SCF energy = -149.867214785564
# converged SCF energy = -149.867214786031
# converged SCF energy = -149.867214786029
# converged SCF energy = -149.867214786029
# converged SCF energy = -149.867214786029
# converged SCF energy = -149.866524260789
# converged SCF energy = -149.867094328516
# converged SCF energy = -149.867220122707
# converged SCF energy = -149.867235260334
# converged SCF energy = -149.867230029452
# converged SCF energy = -149.867223915557
# converged SCF energy = -149.867219848953
# converged SCF energy = -149.867217500494
# converged SCF energy = -149.867216218531
# converged SCF energy = -149.867215535527
# converged SCF energy = -149.867215176899
# converged SCF energy = -149.867215176956
# converged SCF energy = -149.867215176573
# converged SCF energy = -149.867215174919
# converged SCF energy = -149.867215176899
# converged SCF energy = -149.867215176899
# converged SCF energy = -149.867215176899
# converged SCF energy = -149.867237848208
# converged SCF energy = -149.867237848206
# converged SCF energy = -149.867237848348
# converged SCF energy = -149.867237848214
# converged SCF energy = -149.867237847882
# converged SCF energy = -149.867237848208
# converged SCF energy = -149.867237848208
# converged SCF energy = -149.867262357719
# converged SCF energy = -149.867251431323
# converged SCF energy = -149.86724532583
# converged SCF energy = -149.867241949877
# converged SCF energy = -149.867240096268
# converged SCF energy = -149.867239078085
# converged SCF energy = -149.867238521842
# converged SCF energy = -149.86723821621
# converged SCF energy = -149.867238049149
# converged SCF energy = -149.86723795786
# converged SCF energy = -149.867237909938
# converged SCF energy = -149.867237910042
# converged SCF energy = -149.867237909939
# converged SCF energy = -149.867237907982
# converged SCF energy = -149.867237909938
# converged SCF energy = -149.867237909938
# converged SCF energy = -149.867237909938
# converged SCF energy = -149.867285190662
# converged SCF energy = -149.867285190746
# converged SCF energy = -149.867285190993
# converged SCF energy = -149.867285190665
# converged SCF energy = -149.867285190662
# converged SCF energy = -149.867285190662
# converged SCF energy = -149.867285190662
# converged SCF energy = -149.867283944607
# converged SCF energy = -149.867284633899
# converged SCF energy = -149.867284930372
# converged SCF energy = -149.867285066996
# converged SCF energy = -149.867285131585
# converged SCF energy = -149.867285161014
# converged SCF energy = -149.86728517729
# converged SCF energy = -149.867285182412
# converged SCF energy = -149.867285188784
# converged SCF energy = -149.86728519082
# converged SCF energy = -149.867285189829
# converged SCF energy = -149.867285189857
# converged SCF energy = -149.867285189699
# converged SCF energy = -149.867285189836
# converged SCF energy = -149.867285189829
# converged SCF energy = -149.867285189829
# converged SCF energy = -149.867285189829
# converged SCF energy = -149.867302804117
# converged SCF energy = -149.867302804191
# converged SCF energy = -149.867302804588
# converged SCF energy = -149.867302806082
# converged SCF energy = -149.867302804117
# converged SCF energy = -149.867302804117
# converged SCF energy = -149.867302804117
# converged SCF energy = -149.867565914739
# converged SCF energy = -149.867565914784
# converged SCF energy = -149.867565914609
# converged SCF energy = -149.867565914722
# converged SCF energy = -149.867565914739
# converged SCF energy = -149.867565914739
# converged SCF energy = -149.867565914739
# converged SCF energy = -149.867928493476
# converged SCF energy = -149.867928493538
# converged SCF energy = -149.867928493373
# converged SCF energy = -149.867928493507
# converged SCF energy = -149.867928493476
# converged SCF energy = -149.867928493476
# converged SCF energy = -149.867928493476
# converged SCF energy = -149.86795088148
# converged SCF energy = -149.867978535717
# converged SCF energy = -149.867978535718
# converged SCF energy = -149.86797853527
# converged SCF energy = -149.867978535747
# converged SCF energy = -149.867978535717
# converged SCF energy = -149.867978535717
# converged SCF energy = -149.867978535717
# converged SCF energy = -149.867962101343
# converged SCF energy = -149.867973800271
# converged SCF energy = -149.867976905912
# converged SCF energy = -149.86797789191
# converged SCF energy = -149.867978257215
# converged SCF energy = -149.86797840668
# converged SCF energy = -149.867978475502
# converged SCF energy = -149.867978506456
# converged SCF energy = -149.867978521612
# converged SCF energy = -149.867978528022
# converged SCF energy = -149.867978532347
# converged SCF energy = -149.867978532397
# converged SCF energy = -149.867978532696
# converged SCF energy = -149.867978532351
# converged SCF energy = -149.867978532346
# converged SCF energy = -149.867978532347
# converged SCF energy = -149.867978532347
# converged SCF energy = -149.867978532309
# converged SCF energy = -149.867978531871
# converged SCF energy = -149.867978530879
# converged SCF energy = -149.867978531483
# converged SCF energy = -149.867978532403
# converged SCF energy = -149.867978531179
# converged SCF energy = -149.867978532672
# converged SCF energy = -149.867978532722
# converged SCF energy = -149.86797853283
# converged SCF energy = -149.867978532657
# converged SCF energy = -149.867978532672
# converged SCF energy = -149.867978532672
# converged SCF energy = -149.867978530698
# converged SCF energy = -149.867973844732
# converged SCF energy = -149.867977476959
# converged SCF energy = -149.867978271309
# converged SCF energy = -149.86797846241
# converged SCF energy = -149.867978510187
# converged SCF energy = -149.86797852515
# converged SCF energy = -149.867978529248
# converged SCF energy = -149.867978533092
# converged SCF energy = -149.867978530964
# converged SCF energy = -149.867978530902
# converged SCF energy = -149.867978532047
# converged SCF energy = -149.867978532048
# converged SCF energy = -149.867978531742
# converged SCF energy = -149.867978532052
# converged SCF energy = -149.867978532047
# converged SCF energy = -149.867978532047
# converged SCF energy = -149.867978532047
# converged SCF energy = -149.867978490425
# converged SCF energy = -149.867978516115
# converged SCF energy = -149.867978525329
# converged SCF energy = -149.867978526986
# converged SCF energy = -149.867978530977
# converged SCF energy = -149.867978531369
# converged SCF energy = -149.867978531554
# converged SCF energy = -149.867978530311
# converged SCF energy = -149.867978531628
# converged SCF energy = -149.867978530799
# converged SCF energy = -149.867978532459
# converged SCF energy = -149.867978532469
# converged SCF energy = -149.867978532012
# converged SCF energy = -149.867978532464
# converged SCF energy = -149.867978532459
# converged SCF energy = -149.867978532459
# converged SCF energy = -149.867978532459
# converged SCF energy = -149.867976778678
# converged SCF energy = -149.867978061368
# converged SCF energy = -149.867978389766
# converged SCF energy = -149.8679784847
# converged SCF energy = -149.867978513621
# converged SCF energy = -149.867978524504
# converged SCF energy = -149.867978528465
# converged SCF energy = -149.867978530013
# converged SCF energy = -149.867978532045
# converged SCF energy = -149.867978531037
# converged SCF energy = -149.867978533491
# converged SCF energy = -149.867978533492
# converged SCF energy = -149.867978533506
# converged SCF energy = -149.867978531547
# converged SCF energy = -149.867978533491
# converged SCF energy = -149.867978533491
# converged SCF energy = -149.867978533491
# converged SCF energy = -149.867978508835
# converged SCF energy = -149.867978521286
# converged SCF energy = -149.867978528869
# converged SCF energy = -149.867978529265
# converged SCF energy = -149.867978530883
# converged SCF energy = -149.867978532038
# converged SCF energy = -149.867978530619
# converged SCF energy = -149.867978531863
# converged SCF energy = -149.867978532648
# converged SCF energy = -149.867978532272
# converged SCF energy = -149.867978531498
# converged SCF energy = -149.867978531491
# converged SCF energy = -149.867978531991
# converged SCF energy = -149.867978531503
# converged SCF energy = -149.867978531498
# converged SCF energy = -149.867978531498
# converged SCF energy = -149.867978531498
# converged SCF energy = -149.867978532811
# converged SCF energy = -149.867978533044
# converged SCF energy = -149.867978533095
# converged SCF energy = -149.867978533202
# converged SCF energy = -149.867978531075
# converged SCF energy = -149.867978533044
# converged SCF energy = -149.867978533044
# converged SCF energy = -149.867978533044
# converged SCF energy = -149.867978532238
# converged SCF energy = -149.867978531952
# converged SCF energy = -149.867978531483
# converged SCF energy = -149.867978531357
# converged SCF energy = -149.867978531298
# converged SCF energy = -149.867978533235
# converged SCF energy = -149.867978533228
# converged SCF energy = -149.86797853325
# converged SCF energy = -149.867978531266
# converged SCF energy = -149.867978533235
# converged SCF energy = -149.867978533235
# converged SCF energy = -149.867978533235
# converged SCF energy = -149.867978756658
# converged SCF energy = -149.867978647138
# converged SCF energy = -149.867978589531
# converged SCF energy = -149.867978563369
# converged SCF energy = -149.867978549207
# converged SCF energy = -149.867978541224
# converged SCF energy = -149.867978536522
# converged SCF energy = -149.867978532893
# converged SCF energy = -149.867978533306
# converged SCF energy = -149.867978531853
# converged SCF energy = -149.867978531476
# converged SCF energy = -149.867978531478
# converged SCF energy = -149.867978531969
# converged SCF energy = -149.867978531481
# converged SCF energy = -149.867978531477
# converged SCF energy = -149.867978531477
# converged SCF energy = -149.867978531476
# converged SCF energy = -149.867978534369
# converged SCF energy = -149.867978533371
# converged SCF energy = -149.867978532289
# converged SCF energy = -149.867978532125
# converged SCF energy = -149.867978531738
# converged SCF energy = -149.867978531765
# converged SCF energy = -149.867978533507
# converged SCF energy = -149.86797853346
# converged SCF energy = -149.867978534
# converged SCF energy = -149.867978531563
# converged SCF energy = -149.867978533507
# converged SCF energy = -149.867978533507
# converged SCF energy = -149.867978533507
# converged SCF energy = -149.867978561387
# converged SCF energy = -149.867978547056
# converged SCF energy = -149.867978539491
# converged SCF energy = -149.867978534564
# converged SCF energy = -149.867978534006
# converged SCF energy = -149.867978532639
# converged SCF energy = -149.867978532144
# converged SCF energy = -149.86797853352
# converged SCF energy = -149.867978533681
# converged SCF energy = -149.867978531646
# converged SCF energy = -149.867978531757
# converged SCF energy = -149.86797853171
# converged SCF energy = -149.867978531645
# converged SCF energy = -149.867978531762
# converged SCF energy = -149.867978531757
# converged SCF energy = -149.867978531757
# converged SCF energy = -149.867978531757
# converged SCF energy = -149.867978531808
# converged SCF energy = -149.867978531809
# converged SCF energy = -149.867978531695
# converged SCF energy = -149.867978531813
# converged SCF energy = -149.867978531808
# converged SCF energy = -149.867978531808
# converged SCF energy = -149.867978531808
# converged SCF energy = -149.867978531908
# converged SCF energy = -149.867978531861
# converged SCF energy = -149.867978531939
# converged SCF energy = -149.867978531913
# converged SCF energy = -149.867978531908
# converged SCF energy = -149.867978531908
# converged SCF energy = -149.867978531908
# converged SCF energy = -149.867978531992
# converged SCF energy = -149.867978531993
# converged SCF energy = -149.867978531879
# converged SCF energy = -149.867978531997
# converged SCF energy = -149.867978531992
# converged SCF energy = -149.867978531992
# converged SCF energy = -149.867978531992
# converged SCF energy = -149.867978532148
# converged SCF energy = -149.86797853215
# converged SCF energy = -149.867978532036
# converged SCF energy = -149.867978532153
# converged SCF energy = -149.867978531686
# converged SCF energy = -149.867978532148
# converged SCF energy = -149.867978532148
# converged SCF energy = -149.867978575929
# converged SCF energy = -149.867978575922
# converged SCF energy = -149.867978576087
# converged SCF energy = -149.867978575939
# converged SCF energy = -149.867978575929
# converged SCF energy = -149.867978575929
# converged SCF energy = -149.867978575929
# converged SCF energy = -149.867978584507
# converged SCF energy = -149.867978584548
# converged SCF energy = -149.867978585
# converged SCF energy = -149.867978582563
# converged SCF energy = -149.867978584507
# converged SCF energy = -149.867978584507
# converged SCF energy = -149.867978584507
# converged SCF energy = -149.867978705052
# converged SCF energy = -149.867978705045
# converged SCF energy = -149.867978704604
# converged SCF energy = -149.867978705061
# converged SCF energy = -149.867978705052
# converged SCF energy = -149.867978705052
# converged SCF energy = -149.867978705052
# converged SCF energy = -149.867978636682
# converged SCF energy = -149.867978676207
# converged SCF energy = -149.867978691591
# converged SCF energy = -149.867978699442
# converged SCF energy = -149.867978702734
# converged SCF energy = -149.867978704331
# converged SCF energy = -149.867978703995
# converged SCF energy = -149.867978703993
# converged SCF energy = -149.867978705776
# converged SCF energy = -149.86797870577
# converged SCF energy = -149.867978705791
# converged SCF energy = -149.867978705781
# converged SCF energy = -149.867978705776
# converged SCF energy = -149.867978705776
# converged SCF energy = -149.867978705776
# converged SCF energy = -149.86797870578
# converged SCF energy = -149.867978705782
# converged SCF energy = -149.867978705333
# converged SCF energy = -149.86797870581
# converged SCF energy = -149.867978703826
# converged SCF energy = -149.867978705781
# converged SCF energy = -149.867978705781
# converged SCF energy = -149.867978709269
# converged SCF energy = -149.867978708273
# converged SCF energy = -149.867978706569
# converged SCF energy = -149.867978707464
# converged SCF energy = -149.867978707504
# converged SCF energy = -149.867978707159
# converged SCF energy = -149.867978705519
# converged SCF energy = -149.867978707463
# converged SCF energy = -149.867978707464
# converged SCF energy = -149.867978707463
# converged SCF energy = -149.867978706156
# converged SCF energy = -149.867978707081
# converged SCF energy = -149.867978706715
# converged SCF energy = -149.867978707516
# converged SCF energy = -149.867978706592
# converged SCF energy = -149.867978707067
# converged SCF energy = -149.867978707471
# converged SCF energy = -149.867978707435
# converged SCF energy = -149.867978707166
# converged SCF energy = -149.867978705527
# converged SCF energy = -149.867978707471
# converged SCF energy = -149.867978707471
# converged SCF energy = -149.867978707471
# converged SCF energy = -149.86797870487
# converged SCF energy = -149.867978707379
# converged SCF energy = -149.86797870744
# converged SCF energy = -149.867978707433
# converged SCF energy = -149.867978707471
# converged SCF energy = -149.867978707471
# converged SCF energy = -149.867978707471
# converged SCF energy = -149.867978707471
# converged SCF energy = -149.867978707471
# converged SCF energy = -149.867978707471
# converged SCF energy = -149.867978707471
# converged SCF energy = -149.865815478567
# converged SCF energy = -149.865815479812
# converged SCF energy = -149.865815478586
# converged SCF energy = -149.865815479888
# converged SCF energy = -149.865815478567
# converged SCF energy = -149.865815478567
# converged SCF energy = -149.865815478567
# converged SCF energy = -149.865450978856
# converged SCF energy = -149.865688208231
# converged SCF energy = -149.865764042091
# converged SCF energy = -149.865792696519
# converged SCF energy = -149.865804844934
# converged SCF energy = -149.865810375066
# converged SCF energy = -149.865812991876
# converged SCF energy = -149.8658142597
# converged SCF energy = -149.86581487763
# converged SCF energy = -149.865815182063
# converged SCF energy = -149.865815334748
# converged SCF energy = -149.865815333434
# converged SCF energy = -149.865815334768
# converged SCF energy = -149.865815333433
# converged SCF energy = -149.865815334748
# converged SCF energy = -149.865815334748
# converged SCF energy = -149.865815333725
# converged SCF energy = -149.865805652296
# converged SCF energy = -149.865810888917
# converged SCF energy = -149.865813214534
# converged SCF energy = -149.865814302523
# converged SCF energy = -149.865814826778
# converged SCF energy = -149.8658150819
# converged SCF energy = -149.865815208149
# converged SCF energy = -149.865815272203
# converged SCF energy = -149.865815304089
# converged SCF energy = -149.865815318156
# converged SCF energy = -149.865815325917
# converged SCF energy = -149.865815325778
# converged SCF energy = -149.865815325908
# converged SCF energy = -149.865815325919
# converged SCF energy = -149.865815325916
# converged SCF energy = -149.865815325916
# converged SCF energy = -149.865815325917
# converged SCF energy = -149.865825781289
# converged SCF energy = -149.86582578115
# converged SCF energy = -149.865825781308
# converged SCF energy = -149.865825781374
# converged SCF energy = -149.865825781289
# converged SCF energy = -149.865825781289
# converged SCF energy = -149.865825781289
# converged SCF energy = -149.86592094613
# converged SCF energy = -149.865920947273
# converged SCF energy = -149.865920946156
# converged SCF energy = -149.865920947426
# converged SCF energy = -149.865920947353
# converged SCF energy = -149.86592094613
# converged SCF energy = -149.865920946129
# converged SCF energy = -149.860383098032
# converged SCF energy = -149.848860626497
# converged SCF energy = -149.864580504265
# converged SCF energy = -149.865872670477
# converged SCF energy = -149.865969440437
# converged SCF energy = -149.865961973744
# converged SCF energy = -149.865946977695
# converged SCF energy = -149.865936204605
# converged SCF energy = -149.86592961473
# converged SCF energy = -149.86592579836
# converged SCF energy = -149.865923641077
# converged SCF energy = -149.865923641027
# converged SCF energy = -149.86592364211
# converged SCF energy = -149.86592364229
# converged SCF energy = -149.865923641077
# converged SCF energy = -149.865923641077
# converged SCF energy = -149.865923641077
# converged SCF energy = -149.860122056289
# converged SCF energy = -149.845516052289
# converged SCF energy = -149.860686581092
# converged SCF energy = -149.865209491204
# converged SCF energy = -149.865889268638
# converged SCF energy = -149.865970145645
# converged SCF energy = -149.865961470025
# converged SCF energy = -149.865946259748
# converged SCF energy = -149.86593597904
# converged SCF energy = -149.865930128507
# converged SCF energy = -149.865926992924
# converged SCF energy = -149.865926992873
# converged SCF energy = -149.865926993922
# converged SCF energy = -149.865926994135
# converged SCF energy = -149.865926992924
# converged SCF energy = -149.865926992924
# converged SCF energy = -149.865926992924
# converged SCF energy = -149.86156234725
# converged SCF energy = -149.858180033877
# converged SCF energy = -149.862466461135
# converged SCF energy = -149.865302007539
# converged SCF energy = -149.865886404669
# converged SCF energy = -149.865966394377
# converged SCF energy = -149.865960844203
# converged SCF energy = -149.865947543635
# converged SCF energy = -149.865938268518
# converged SCF energy = -149.865932933739
# converged SCF energy = -149.865930064426
# converged SCF energy = -149.865930064401
# converged SCF energy = -149.865930064486
# converged SCF energy = -149.865930064415
# converged SCF energy = -149.865930064426
# converged SCF energy = -149.865930064427
# converged SCF energy = -149.865930064427
# converged SCF energy = -149.865930289977
# converged SCF energy = -149.865930291119
# converged SCF energy = -149.865930288981
# converged SCF energy = -149.86593029127
# converged SCF energy = -149.865930289977
# converged SCF energy = -149.865930289977
# converged SCF energy = -149.865930289977
# converged SCF energy = -149.865930117344
# converged SCF energy = -149.8659302039
# converged SCF energy = -149.865930246617
# converged SCF energy = -149.865930269038
# converged SCF energy = -149.865930280876
# converged SCF energy = -149.86593028545
# converged SCF energy = -149.865930288927
# converged SCF energy = -149.86593028893
# converged SCF energy = -149.865930289356
# converged SCF energy = -149.865930289901
# converged SCF energy = -149.865930291131
# converged SCF energy = -149.865930292273
# converged SCF energy = -149.865930291143
# converged SCF energy = -149.865930289803
# converged SCF energy = -149.865930291131
# converged SCF energy = -149.865930291131
# converged SCF energy = -149.865930291131
# converged SCF energy = -149.86592719513
# converged SCF energy = -149.865928791428
# converged SCF energy = -149.865929562759
# converged SCF energy = -149.865929938384
# converged SCF energy = -149.865930118692
# converged SCF energy = -149.865930207995
# converged SCF energy = -149.865930249027
# converged SCF energy = -149.86593027003
# converged SCF energy = -149.865930280315
# converged SCF energy = -149.865930286459
# converged SCF energy = -149.865930287825
# converged SCF energy = -149.865930287896
# converged SCF energy = -149.865930288823
# converged SCF energy = -149.865930286498
# converged SCF energy = -149.865930287825
# converged SCF energy = -149.865930287825
# converged SCF energy = -149.865930287825
# converged SCF energy = -149.865930179823
# converged SCF energy = -149.865930238629
# converged SCF energy = -149.865930264039
# converged SCF energy = -149.865930277715
# converged SCF energy = -149.865930281567
# converged SCF energy = -149.865930284844
# converged SCF energy = -149.865930286336
# converged SCF energy = -149.865930287072
# converged SCF energy = -149.865930288544
# converged SCF energy = -149.865930288615
# converged SCF energy = -149.865930288556
# converged SCF energy = -149.865930288521
# converged SCF energy = -149.865930288544
# converged SCF energy = -149.865930288544
# converged SCF energy = -149.865930288544
# converged SCF energy = -149.865930286903
# converged SCF energy = -149.865930288444
# converged SCF energy = -149.865930288472
# converged SCF energy = -149.865930288544
# converged SCF energy = -149.865930288544
# converged SCF energy = -149.865930288544
# converged SCF energy = -149.865930288544
# converged SCF energy = -149.865930288544
# converged SCF energy = -149.865930288544
# converged SCF energy = -149.865930288544
# converged SCF energy = -149.865930288544
# [[ 1.38757071e+00 -1.27018206e+00  1.01458319e+00  9.96837087e+01
#    8.66132745e+01  1.11094543e+02]
#  [ 1.14178812e+00  7.72131411e-02 -8.42391665e-01  7.73440209e+01
#    3.02343631e+01  1.33583465e+02]] [-149.86797871 -149.86593029]

# %%
#Dismiss candidates that are really similar to each other
#(just by comparing all cartesian coordinates)
candidates=[]
candidates_coord=[]

for i in range(len(minimos.xl)):
        water_molecule = Molecule(water_dict).translate(0, x=1.5, y=1.5, z=1.5)

        water_molecule_2 = Molecule(water_dict)
        water_molecule_2 = water_molecule_2.translate(0,x=minimos.xl[i][0],y=minimos.xl[i][1],z=minimos.xl[i][2])
        water_molecule_2 = water_molecule_2.rotate(0,minimos.xl[i][3],minimos.xl[i][4],minimos.xl[i][5])

        water_cluster_optimized = water_molecule.add_fragments(water_molecule_2)

        if candidates: #si la lista no está vacía
                flag = 0
                for k in range(len(candidates)):
                        if np.all(np.isclose(water_cluster_optimized.cartesian_coordinates, candidates_coord[k],atol=0.05)):
                                flag = 1 #valores muy cercanos
                        else:
                                pass
                if flag != 1:
                        candidates.append(water_cluster_optimized)
                        candidates_coord.append(water_cluster_optimized.cartesian_coordinates)
        else:
                candidates.append(water_cluster_optimized)
                candidates_coord.append(water_cluster_optimized.cartesian_coordinates)

# %%
#Save results on file

#Clean file
with open('water.xyz', 'w') as f:
                f.write(" ")


for i in range(len(candidates)):
        mol = gto.Mole()
        mol.fromstring(str(candidates[i]))
        mol.build()

        mf = scf.RHF(mol)
        mf.kernel()
        energia = mf.energy_tot()


        with open('water.xyz', 'a') as f:

                f.write("---------------    Candidate %.0f    ---------------\n" % int(i+1))
                f.write(str(candidates[i]))
                f.write("Energy: %.6f \n" % mf.energy_tot())
# Out:
# converged SCF energy = -149.867978707471
# converged SCF energy = -149.865930288544

# %%
## See Final molecule.

import py3Dmol

for i in range(len(candidates)):
    xyz_view = py3Dmol.view(width=300,height=200)
    xyz_view.addModel(str(candidates[i]),'xyz')
    xyz_view.setStyle({'stick':{}})

    xyz_view.zoomTo()
    xyz_view.show()
# Out:
# <div id="3dmolviewer_504465153398932"  style="position: relative; width: 300px; height: 200px">
#         <p id="3dmolwarning_504465153398932" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_504465153398932 = null;
# var warn = document.getElementById("3dmolwarning_504465153398932");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_504465153398932 = $3Dmol.createViewer($("#3dmolviewer_504465153398932"),{backgroundColor:"white"});
# viewer_504465153398932.zoomTo();
# 	viewer_504465153398932.addModel("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 1.50000000\t 1.50000000\t 1.50000000\nH\t 2.08708000\t 2.25754000\t 1.50000000\nH\t 0.91292000\t 2.25754000\t 1.50000000\nO\t 1.38289828\t-1.26837024\t 0.99778807\nH\t 1.41216886\t-0.64280644\t 1.72328304\nH\t 1.43713338\t-0.41123497\t 0.57245588\n","xyz");
# 	viewer_504465153398932.setStyle({"stick": {}});
# 	viewer_504465153398932.zoomTo();
# viewer_504465153398932.render();
# });
# </script>
# <div id="3dmolviewer_504465155096536"  style="position: relative; width: 300px; height: 200px">
#         <p id="3dmolwarning_504465155096536" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_504465155096536 = null;
# var warn = document.getElementById("3dmolwarning_504465155096536");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_504465155096536 = $3Dmol.createViewer($("#3dmolviewer_504465155096536"),{backgroundColor:"white"});
# viewer_504465155096536.zoomTo();
# 	viewer_504465155096536.addModel("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 1.50000000\t 1.50000000\t 1.50000000\nH\t 2.08708000\t 2.25754000\t 1.50000000\nH\t 0.91292000\t 2.25754000\t 1.50000000\nO\t 1.08873353\t 0.14462202\t-0.90619035\nH\t 1.21314630\t 0.00777178\t 0.03419428\nH\t 1.91251363\t 0.59181920\t-0.70636339\n","xyz");
# 	viewer_504465155096536.setStyle({"stick": {}});
# 	viewer_504465155096536.zoomTo();
# viewer_504465155096536.render();
# });
# </script>

# %%
from src.base_molecule import Molecule

water_molecule=[("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
water = Molecule(water_molecule)
#print(water)
water2 = water.add_fragments(water_molecule)
#print(water2)
iodine =[("I", 0, 0, 0)]
w5_I = Molecule(
    iodine,
    water
)
print(w5_I)


# let's MOVE 2 units on xy axes the first molecule (I) and rotate 180 deg around z-axis the second molecule (water)
#w5_I_moved_rotated = w5_I.translate(0, x=2, y=2, z=3).rotate(1, x=0, y=0, z=180)  #Cambia el orden de los átomos en la molécula
w5_I_moved_rotated = w5_I.translate(0, x=2, y=2, z=3)  #Cambia el orden de los átomos en la molécula

print(w5_I_moved_rotated)
# Out:
# 	4
# --system of 2 molecules and 4 total individual atoms--
# I	 0.00000000	 0.00000000	 0.00000000
# O	 0.00000000	 0.00000000	 0.00000000
# H	 0.58708000	 0.75754000	 0.00000000
# H	-0.58708000	 0.75754000	 0.00000000
#
# 	4
# --system of 2 molecules and 4 total individual atoms--
# O	 0.00000000	 0.00000000	 0.00000000
# H	 0.58708000	 0.75754000	 0.00000000
# H	-0.58708000	 0.75754000	 0.00000000
# I	 2.00000000	 2.00000000	 3.00000000

# %%
# Atomic Simulation Environment
# https://wiki.fysik.dtu.dk/ase/index.html
# !pip install --upgrade --user ase


# ChemML
# https://hachmannlab.github.io/chemml/index.html
# !pip install chemml

# %%
# NGLview
# https://github.com/nglviewer/nglview
# !pip install nglview

# ---------------------------------------
# pytraj 
# https://amber-md.github.io/pytraj/latest/index.html
# !pip install pytraj
