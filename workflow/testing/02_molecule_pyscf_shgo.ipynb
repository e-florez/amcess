# %% [markdown]
# # Import a Molecules/Atom from cartesian coordinates:
# **Task:**
# 1. Create a Molecule object from its cartesian coordinates
# 2. Ask for its atomic and molecular properties

# %% [markdown]
# ## [Water molecule](https://en.wikipedia.org/wiki/Properties_of_water) ($H_{2}O$):
#
# <img
# src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b7/H2O_2D_labelled.svg/2560px-H2O_2D_labelled.svg.png"
# alt="water"
# width="200"
# height="100"
# />
#
# ### Properties:
# - Number of molecules: 1
# - Number of atoms: 3
# - Atomic symbols: O, H, H
# - Atomic masses [g/mol]:
#     - O: 15.999
#     - H: 1.008
#     - H: 1.008
# - Molar mass [g/mol]: 18.015
# - Cartesian coordinates [Angstrom]:
#     ```XYZ
#     O    0.00000    0.00000    0.00000
#     H    0.58708    0.75754    0.00000
#     H    0.58708   -0.75754    0.00000
#     ```
# - Bond distance [Angstrom]:
#     - H-O: 0.9584 (95.84 pm)
#     - H-H: 1.5151
# - Bond angle [Degrees]:
#     - H-O-H: 104.45
#     - H-H-O: 37.78

# %%
# crating the path (PYTHONPATH) to our module.
# assuming that our 'src' directory is out ('..') of our current directory 
import os
import sys
module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Import Molecule Class
from src.base_molecule import Molecule

# %%
# Creates a molecule. You can use a list, a dictionary (the key MUST be "atoms")
# or another molecule object (see below)

# 1 Option
water=[("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
water_molecule = Molecule(water)

# 2 Option
water_dict = {"atoms": [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]}
water_molecule = Molecule(water_dict)

# %%
## See initial molecule.

import py3Dmol

water_molecule = Molecule(water_dict)
water_molecule = water_molecule.translate(0, x=1.5, y=1.5, z=1.5)
bi_water = water_molecule.add_fragments(water_dict)


xyz_view = py3Dmol.view(width=300,height=200)
xyz_view.addModel(str(bi_water),'xyz')
xyz_view.setStyle({'stick':{}})
# Out:
# <div id="3dmolviewer_48915818794903"  style="position: relative; width: 300px; height: 200px">
#         <p id="3dmolwarning_48915818794903" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_48915818794903 = null;
# var warn = document.getElementById("3dmolwarning_48915818794903");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_48915818794903 = $3Dmol.createViewer($("#3dmolviewer_48915818794903"),{backgroundColor:"white"});
# viewer_48915818794903.zoomTo();
# 	viewer_48915818794903.addModel("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 1.50000000\t 1.50000000\t 1.50000000\nH\t 2.08708000\t 2.25754000\t 1.50000000\nH\t 0.91292000\t 2.25754000\t 1.50000000\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\n","xyz");
# 	viewer_48915818794903.setStyle({"stick": {}});
# viewer_48915818794903.render();
# });
# </script>

# %%
import numpy as np
from scipy.optimize import shgo
from pyscf import gto, scf


def optimization(x):
    """Funcion a optimizar. Primero se introduce la molécula de agua (water_dict), 
    luego, con la clase Molecule la trasladamos una cierta distancia (x=y=z=1.5) y luego
    agregamos el fragmento water_dict, para tener dos moléculas de agua separadas en 1.5 angs en todas direcciones. 

    Luego, a la molécula de 2 aguas, la trasladamos y rotamos en función de x, un 1-D array.
    A esa molécula, le calculanos la energía, siguiendo la base por defecto y RHF.  
    Parameters
    ----------
    x : [1-D Array, de 6 variables, en este caso]
        [variables x,y,z de traslación y los siguientes 3 de rotación]

    Returns
    -------
    []
        [Retorna la energía total del sistema, dado los parámetros en x]
    """
    

    water_molecule = Molecule(water_dict)
    water_molecule = water_molecule.translate(0, x=1.5, y=1.5, z=1.5)

    water_molecule_2 = Molecule(water_dict)
    water_molecule_2 = water_molecule_2.translate(0,x=x[0],y=x[1],z=x[2])
    water_molecule_2 = water_molecule_2.rotate(0,x[3],x[4],x[5])
    
    water_cluster = water_molecule.add_fragments(water_molecule_2)
    
    #Imprimir esto es caro... debería fuera imprimir sólo las geometrías finales
    #with open('water.xyz', 'w') as f:
    #    f.write(str(water_cluster))

    
    mol = gto.Mole()
    #mol.atom = "water.xyz"
    mol.fromstring(str(water_cluster))
    mol.build(basis = 'sto-3g')
    

    mf = scf.RHF(mol)
    mf.kernel()
    
    return mf.energy_tot()

water_dict = {"atoms": [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]}
bounds = [(-1.5,1.5),(-1.5,1.5),(-2.5,2.5),(0,180),(0,90),(0,180)]

#aquí habría que probar con el método sobol, y también con otros métodos de optimización. 
minimos = shgo(optimization, bounds=bounds, sampling_method='simplicial')

print(minimos.xl, minimos.funl)



#Primera vez: demoró 24 minutos.
#Segunda vez: demoró 6 minutos
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo_lib/triangulation.py in __getitem__(self, x, indexed)
#     629         try:
# --> 630             return self.cache[x]
#     631         except KeyError:
#
# KeyError: (0, 0, 0, 0, 0, 0)
#
# During handling of the above exception, another exception occurred:
#
# BasisNotFoundError                        Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pyscf/gto/basis/__init__.py in load(filename_or_basisname, symb, optimize)
#     477         try:
# --> 478             return parse_nwchem.parse(filename_or_basisname, symb)
#     479         except BasisNotFoundError:
#
# ~/.local/lib/python3.8/site-packages/pyscf/gto/basis/parse_nwchem.py in parse(string, symb, optimize)
#      98         if not string:
# ---> 99             raise BasisNotFoundError('Basis not found for %s' % symb)
#     100
#
# BasisNotFoundError: Basis not found for O
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pyscf/gto/basis/__init__.py in load(filename_or_basisname, symb, optimize)
#     480             try:
# --> 481                 return parse_nwchem.parse(filename_or_basisname)
#     482             except IndexError:
#
# ~/.local/lib/python3.8/site-packages/pyscf/gto/basis/parse_nwchem.py in parse(string, symb, optimize)
#     106             raw_basis.append(dat)
# --> 107     return _parse(raw_basis, optimize)
#     108
#
# ~/.local/lib/python3.8/site-packages/pyscf/gto/basis/parse_nwchem.py in _parse(raw_basis, optimize)
#     119         elif dat[0].isalpha():
# --> 120             key = dat.split()[1].upper()
#     121             if key == 'SP':
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# BasisNotFoundError                        Traceback (most recent call last)
# /tmp/ipykernel_1976396/686579842.py in <module>
#      52
#      53 #aquí habría que probar con el método sobol, y también con otros métodos de optimización.
# ---> 54 minimos = shgo(optimization, bounds=bounds, sampling_method='simplicial')
#      55
#      56 print(minimos.xl, minimos.funl)
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in shgo(func, bounds, args, constraints, n, iters, callback, minimizer_kwargs, options, sampling_method)
#     419
#     420     # Run the algorithm, process results and test success
# --> 421     shc.construct_complex()
#     422
#     423     if not shc.break_routine:
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in construct_complex(self)
#     724                 break
#     725             # Iterate complex, process minimisers
# --> 726             self.iterate()
#     727             self.stopping_criteria()
#     728
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in iterate(self)
#     867
#     868     def iterate(self):
# --> 869         self.iterate_complex()
#     870
#     871         # Build minimizer pool
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in iterate_hypercube(self)
#     886         if self.n_sampled == 0:
#     887             # Initial triangulation of the hyper-rectangle
# --> 888             self.HC = Complex(self.dim, self.func, self.args,
#     889                               self.symmetry, self.bounds, self.g_cons,
#     890                               self.g_args)
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo_lib/triangulation.py in __init__(self, dim, func, func_args, symmetry, bounds, g_cons, g_args)
#      23
#      24         # Generate n-cube here:
# ---> 25         self.n_cube(dim, symmetry=symmetry)
#      26
#      27         # TODO: Assign functions to a the complex instead
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo_lib/triangulation.py in n_cube(self, dim, symmetry, printout)
#      74         else:
#      75             self.C0 = Cell(0, 0, origin, supremum)  # Initial cell object
# ---> 76             self.C0.add_vertex(self.V[origintuple])
#      77             self.C0.add_vertex(self.V[supremumtuple])
#      78
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo_lib/triangulation.py in __getitem__(self, x, indexed)
#     632             if indexed:
#     633                 self.index += 1
# --> 634                 xval = Vertex(x, bounds=self.bounds,
#     635                               func=self.func, func_args=self.func_args,
#     636                               g_cons=self.g_cons,
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo_lib/triangulation.py in __init__(self, x, bounds, func, func_args, g_cons, g_cons_args, nn, index)
#     555                         break
#     556             if self.feasible:
# --> 557                 self.f = func(x_a, *func_args)
#     558
#     559         if nn is not None:
#
# /tmp/ipykernel_1976396/686579842.py in optimization(x)
#      41     mol.fromstring(str(water_cluster))
#      42     #mol.build(basis = 'sto-3g')
# ---> 43     mol.build(basis = 'TZ')
#      44
#      45     mf = scf.RHF(mol)
#
# ~/.local/lib/python3.8/site-packages/pyscf/gto/mole.py in build(self, dump_input, parse_arg, verbose, output, max_memory, atom, basis, unit, nucmod, ecp, charge, spin, symmetry, symmetry_subgroup, cart)
#    2344         else:
#    2345             _basis = self.basis
# -> 2346         self._basis = self.format_basis(_basis)
#    2347
#    2348 # TODO: Consider ECP info in point group symmetry initialization
#
# ~/.local/lib/python3.8/site-packages/pyscf/gto/mole.py in format_basis(self, basis_tab)
#    2435     @lib.with_doc(format_basis.__doc__)
#    2436     def format_basis(self, basis_tab):
# -> 2437         return format_basis(basis_tab)
#    2438
#    2439     @lib.with_doc(format_ecp.__doc__)
#
# ~/.local/lib/python3.8/site-packages/pyscf/gto/mole.py in format_basis(basis_tab)
#     417     for atom, atom_basis in basis_tab.items():
#     418         symb = _atom_symbol(atom)
# --> 419         fmt_basis[symb] = basis_converter(symb, atom_basis)
#     420
#     421         if len(fmt_basis[symb]) == 0:
#
# ~/.local/lib/python3.8/site-packages/pyscf/gto/mole.py in converter(symb, raw_basis)
#     443     def converter(symb, raw_basis):
#     444         if isinstance(raw_basis, (str, unicode)):
# --> 445             bset = load(str(raw_basis), _std_symbol_without_ghost(symb))
#     446         elif (any(isinstance(x, (str, unicode)) for x in raw_basis)
#     447               # The first element is the basis of internal format
#
# ~/.local/lib/python3.8/site-packages/pyscf/gto/mole.py in load(basis_name, symb)
#     439             return uncontract(basis.load(basis_name[3:], symb))
#     440         else:
# --> 441             return basis.load(basis_name, symb)
#     442
#     443     def converter(symb, raw_basis):
#
# ~/.local/lib/python3.8/site-packages/pyscf/gto/basis/__init__.py in load(filename_or_basisname, symb, optimize)
#     481                 return parse_nwchem.parse(filename_or_basisname)
#     482             except IndexError:
# --> 483                 raise BasisNotFoundError('Invalid basis name %s' % filename_or_basisname)
#     484         except IndexError:
#     485             raise BasisNotFoundError(filename_or_basisname)
#
# BasisNotFoundError: Invalid basis name TZ

# %%
#Dismiss candidates that are really similar to each other

for i in range(len(minimos.xl)):
        water_molecule = Molecule(water_dict)
        water_molecule = water_molecule.translate(0, x=1.5, y=1.5, z=1.5)

        water_molecule_2 = Molecule(water_dict)
        water_molecule_2 = water_molecule_2.translate(0,x=minimos.xl[i][0],y=minimos.xl[i][1],z=minimos.xl[i][2])
        water_molecule_2 = water_molecule_2.rotate(0,minimos.xl[i][3],minimos.xl[i][4],minimos.xl[i][5])

        water_cluster_optimized = water_molecule.add_fragments(water_molecule_2)

        if candidates: #si la lista no está vacía
                for k in range(len(candidates)):
                        if np.all(np.isclose(water_cluster_optimized.cartesian_coordinates, candidates_coord[k],atol=0.05)):
                                pass #valores muy cercanos
                        else:
                                candidates.append(water_cluster_optimized)
                                candidates_coord.append(water_cluster_optimized.cartesian_coordinates)
        else:
                candidates.append(water_cluster_optimized)
                candidates_coord.append(water_cluster_optimized.cartesian_coordinates)

# %%
#Save results on file

#Clean file
with open('water.xyz', 'w') as f:
                f.write(" ")
candidates=[]
candidates_coord=[]



for i in range(len(candidates)):
        mol = gto.Mole()
        mol.fromstring(str(candidates[i]))
        mol.build()

        mf = scf.RHF(mol)
        mf.kernel()
        energia = mf.energy_tot()


        with open('water.xyz', 'a') as f:

                f.write("---------------    Candidate %.0f    ---------------\n" % int(i+1))
                f.write(str(candidates[i]))
                f.write("Energy: %.6f \n" % mf.energy_tot())

# %%
## See Final molecule.

import py3Dmol

for i in range(len(candidates)):
    xyz_view = py3Dmol.view(width=300,height=200)
    xyz_view.addModel(str(candidates[i]),'xyz')
    xyz_view.setStyle({'stick':{}})

    xyz_view.zoomTo()
    xyz_view.show()
# Out:
# <div id="3dmolviewer_485770277212546"  style="position: relative; width: 300px; height: 200px">
#         <p id="3dmolwarning_485770277212546" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_485770277212546 = null;
# var warn = document.getElementById("3dmolwarning_485770277212546");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_485770277212546 = $3Dmol.createViewer($("#3dmolviewer_485770277212546"),{backgroundColor:"white"});
# viewer_485770277212546.zoomTo();
# 	viewer_485770277212546.addModel("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 1.50000000\t 1.50000000\t 1.50000000\nH\t 2.08708000\t 2.25754000\t 1.50000000\nH\t 0.91292000\t 2.25754000\t 1.50000000\nO\t-1.27624185\t 1.66932539\t 2.33873703\nH\t-1.27624628\t 0.91176525\t 1.75168302\nH\t-1.27623742\t 0.91180553\t 2.92584302\n","xyz");
# 	viewer_485770277212546.setStyle({"stick": {}});
# 	viewer_485770277212546.zoomTo();
# viewer_485770277212546.render();
# });
# </script>

# %%
# Atomic Simulation Environment
# https://wiki.fysik.dtu.dk/ase/index.html
# !pip install --upgrade --user ase


# ChemML
# https://hachmannlab.github.io/chemml/index.html
# !pip install chemml

# %%
# NGLview
# https://github.com/nglviewer/nglview
# !pip install nglview

# ---------------------------------------
# pytraj 
# https://amber-md.github.io/pytraj/latest/index.html
# !pip install pytraj
