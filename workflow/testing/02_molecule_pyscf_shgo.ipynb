# %% [markdown]
# # Import a Molecules/Atom from cartesian coordinates:
# **Task:**
# 1. Create a Molecule object from its cartesian coordinates
# 2. Ask for its atomic and molecular properties

# %% [markdown]
# ## [Water molecule](https://en.wikipedia.org/wiki/Properties_of_water) ($H_{2}O$):
#
# <img
# src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b7/H2O_2D_labelled.svg/2560px-H2O_2D_labelled.svg.png"
# alt="water"
# width="200"
# height="100"
# />
#
# ### Properties:
# - Number of molecules: 1
# - Number of atoms: 3
# - Atomic symbols: O, H, H
# - Atomic masses [g/mol]:
#     - O: 15.999
#     - H: 1.008
#     - H: 1.008
# - Molar mass [g/mol]: 18.015
# - Cartesian coordinates [Angstrom]:
#     ```XYZ
#     O    0.00000    0.00000    0.00000
#     H    0.58708    0.75754    0.00000
#     H    0.58708   -0.75754    0.00000
#     ```
# - Bond distance [Angstrom]:
#     - H-O: 0.9584 (95.84 pm)
#     - H-H: 1.5151
# - Bond angle [Degrees]:
#     - H-O-H: 104.45
#     - H-H-O: 37.78

# %%
# crating the path (PYTHONPATH) to our module.
# assuming that our 'src' directory is out ('..') of our current directory 
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Import Molecule Class
from src.base_molecule import Molecule

# %%
# Creates a molecule. You can use a list, a dictionary (the key MUST be "atoms")
# or another molecule object (see below)

# 1 Option
water=[("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
water_molecule = Molecule(water)

# 2 Option
water_dict = {"atoms": [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]}
water_molecule = Molecule(water_dict)

h2_dict= {"atoms": [("H", 0, 0, 0), ("H", 0.50000, 0, 0)]}

# %%
## See initial molecule.

import py3Dmol

water_molecule = Molecule(water_dict)
water_molecule = water_molecule.translate(0, x=1.5, y=1.5, z=1.5)
bi_water = water_molecule.add_fragments(water_dict)


xyz_view = py3Dmol.view(width=300,height=200)
xyz_view.addModel(str(bi_water),'xyz')
xyz_view.setStyle({'stick':{}})
# Out:
# <div id="3dmolviewer_16330404529859333"  style="position: relative; width: 300px; height: 200px">
#         <p id="3dmolwarning_16330404529859333" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16330404529859333 = null;
# var warn = document.getElementById("3dmolwarning_16330404529859333");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16330404529859333 = $3Dmol.createViewer($("#3dmolviewer_16330404529859333"),{backgroundColor:"white"});
# viewer_16330404529859333.zoomTo();
# 	viewer_16330404529859333.addModel("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 1.50000000\t 1.50000000\t 1.50000000\nH\t 2.08708000\t 2.25754000\t 1.50000000\nH\t 0.91292000\t 2.25754000\t 1.50000000\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\n","xyz");
# 	viewer_16330404529859333.setStyle({"stick": {}});
# viewer_16330404529859333.render();
# });
# </script>

# %%
from copy import deepcopy
from numpy import random
import numpy as np

def random_move(initial_cluster : Molecule, fragment = 0):
    # Random step of every fragment, staying inside sphere
    random_gen = random.default_rng()

    #Leave this until the mentioned methods are modified.
    if not (initial_cluster.translate(0, x=1.2, y=1.9, z=1.3).rotate(0, x=10, y=22, z=69) == initial_cluster.translate(0, x=1.2, y=1.9, z=1.3).rotate(0, x=10, y=22, z=69) ):
        pass
    else:
        "SE ARREGLO EL MODO EN QUE SE ROTAN Y TRASLADAN LOS FRAGMENTOS. CAMBIAR dentro del loop i (total_steps)"

    #Approximately 3 bohr radius for each atom
    sphere_radius = initial_cluster.total_atoms*3*0.5


    #All fragments will be moved AND rotated
    final_cluster_serie_xyz = ""


    final_cluster = deepcopy(initial_cluster)
    for j in range(0,final_cluster.total_fragments):
        # angle between [0, 360)
        ax = random_gen.uniform() * 360
        ay = random_gen.uniform() * 360
        az = random_gen.uniform() * 360

        # moving between [-move, +move]
        move = sphere_radius / 1.6 #/ 2
        tx = move * (random_gen.uniform() - 0.5 )
        ty = move * (random_gen.uniform() - 0.5 )
        tz = move * (random_gen.uniform() - 0.5 )

        final_cluster = final_cluster.translate(0, x=tx, y=ty, z=tz)
        final_cluster = final_cluster.rotate(final_cluster.total_fragments-1, x=ax, y=ay, z=az)

    # saving coordinates as a string 
    final_cluster_serie_xyz += final_cluster.xyz

    #Checking if any fragments falls out of the sphere (ALREADY CHECKED)
    import math as m
    if m.sqrt(final_cluster.coordinates[1][1]*final_cluster.coordinates[1][1]+final_cluster.coordinates[1][2]*final_cluster.coordinates[1][2]+final_cluster.coordinates[1][3]*final_cluster.coordinates[1][3]) > sphere_radius:
        print("un fragmento está cayendo fuera de la esfera")
    return final_cluster


def controled_move(initial_cluster : Molecule, displacements, angular_rotations):
    #Leave this until the mentioned methods are modified.
    if not (initial_cluster.translate(0, x=1.2, y=1.9, z=1.3).rotate(0, x=10, y=22, z=69) == initial_cluster.translate(0, x=1.2, y=1.9, z=1.3).rotate(0, x=10, y=22, z=69) ):
        pass
    else:
        "SE ARREGLO EL MODO EN QUE SE ROTAN Y TRASLADAN LOS FRAGMENTOS. CAMBIAR dentro del loop i (total_steps)"

    #Approximately 3 bohr radius for each atom
    sphere_radius = initial_cluster.total_atoms*3*0.5

    #All fragments MAY be moved AND rotated
    #final_cluster_serie_xyz = ""

    final_cluster = deepcopy(initial_cluster)


    for i in range(final_cluster.total_fragments):

        if final_cluster.total_fragments > 2:
            final_cluster = final_cluster.translate(0, x=displacements[i][0], y=displacements[i][1], z=displacements[i][2])
            final_cluster = final_cluster.rotate(final_cluster.total_fragments-1, x=angular_rotations[i][0], y=angular_rotations[i][0], z=angular_rotations[i][0])


        elif final_cluster.total_fragments == 2:
            final_cluster = final_cluster.translate(final_cluster.total_fragments-1, x=displacements[i][0], y=displacements[i][1], z=displacements[i][2])
            final_cluster = final_cluster.rotate(final_cluster.total_fragments-1, x=angular_rotations[i][0], y=angular_rotations[i][0], z=angular_rotations[i][0])
        else:
            pass

    
    #Rude checking if any fragments falls out of the sphere (ALREADY CHECKED)
    import math as m
    if m.sqrt(final_cluster.coordinates[0][1]*final_cluster.coordinates[0][1]+final_cluster.coordinates[0][2]*final_cluster.coordinates[0][2]+final_cluster.coordinates[0][3]*final_cluster.coordinates[0][3]) > sphere_radius:
        print("un fragmento está cayendo fuera de la esfera")
    return final_cluster


#Visualization
def visualization_random_process(serie_string : str, n_atoms):
    #Approximately 3 bohr radius for each atom
    sphere_radius = n_atoms*3*0.5
    xyz_view = py3Dmol.view(width=1000,height=700)
    xyz_view.addModelsAsFrames(serie_string,'xyz')
    xyz_view.setStyle({'sphere': {'radius': 0.8}})
    xyz_view.addSphere({'center': {'x':0, 'y':0, 'z':0}, 
        'radius': sphere_radius , 
        'color' :'yellow',
        'alpha': 0.5,
        })

    xyz_view.animate({'loop': "forward", 'speed': 1, 'reps': 10})
    xyz_view.zoomTo()
    xyz_view.show()


#### Funciones para combinar con shgo:
from scipy.optimize import shgo
from pyscf import gto, scf



def optimization_juan_outer(cluster_of_interest):

    sphere_radius = cluster_of_interest.total_atoms*3*0.5
    discretization = sphere_radius / 1.6
    bounds = np.array([(-discretization,discretization),(-discretization,discretization),(-discretization,discretization),(0,180),(0,90),(0,180)])
    shgo_tolerance_dict = {"ftol" : 1e-6} # Default is 1e-12
    shgo_options_dict = {"options" : shgo_tolerance_dict}
    bounds_full = np.repeat(bounds,cluster_of_interest.total_fragments-1,axis=0)
    
    #aquí habría que probar con el método simplicial, halton, sobol.
    minimos = shgo(optimization_juan_inner, bounds=bounds_full, minimizer_kwargs=shgo_options_dict, sampling_method='sobol')

    return minimos

def optimization_juan_inner(x):
    global serie_of_interest_xyz_last
    #No tengo modos de meter como argumento la molécula... 
    
    displacements= [ np.zeros(3) ]
    angular_rotations= [ np.zeros(3) ]

    for i in range(cluster_of_interest.total_fragments-1):
        displacements.append(x[i*3:i*3+3])
        angular_rotations.append(x[(cluster_of_interest.total_fragments-1+i)*3:(cluster_of_interest.total_fragments+i)*3])

    #print("x:",x)
    #print("angulos",angular_rotations,"radio",cluster_of_interest.total_atoms*3*0.5)
    candidate_to_test = controled_move(cluster_of_interest, displacements, angular_rotations)
    serie_of_interest_xyz_last += candidate_to_test.xyz

    mol = gto.Mole()
    mol.fromstring(str(candidate_to_test))
    mol.build(basis = 'sto-3g')
    

    mf = scf.RHF(mol)
    mf.kernel()
    
    return mf.energy_tot()
# Out:
# converged SCF energy = -149.860379018807
# converged SCF energy = -139.469987456288
# converged SCF energy = -149.860126133734
# converged SCF energy = -149.860381413053
# converged SCF energy = -149.832777285796
# converged SCF energy = -149.860307431835
# converged SCF energy = -149.860954724503
# converged SCF energy = -149.860220946509
# converged SCF energy = -149.85983331873
# converged SCF energy = -149.860625638522
# converged SCF energy = -149.860575715455
# converged SCF energy = -149.8598897025
# converged SCF energy = -149.860384883203
# converged SCF energy = -149.860530102889
# converged SCF energy = -149.859665265138
# converged SCF energy = -149.860358222985
# converged SCF energy = -149.859937801583
# converged SCF energy = -149.860861235115
# converged SCF energy = -149.860174164399
# converged SCF energy = -149.865761776355
# converged SCF energy = -149.861668701689
# converged SCF energy = -149.86017892548
# converged SCF energy = -149.860034230922
# converged SCF energy = -149.860455815564
# converged SCF energy = -149.860267536613
# converged SCF energy = -149.860158910845
# converged SCF energy = -149.859980247789
# converged SCF energy = -149.860821146519
# converged SCF energy = -149.860214481313
# converged SCF energy = -149.860991796018
# converged SCF energy = -149.860582512484
# converged SCF energy = -149.859854540196
# converged SCF energy = -149.860042779753
# converged SCF energy = -149.860395222958
# converged SCF energy = -149.860813148654
# converged SCF energy = -149.859288385984
# converged SCF energy = -149.860765730317
# converged SCF energy = -149.860193082812
# converged SCF energy = -149.859961369779
# converged SCF energy = -149.860716147766
# converged SCF energy = -149.860824116204
# converged SCF energy = -149.858938807279
# converged SCF energy = -149.860231967813
# converged SCF energy = -149.863679926946
# converged SCF energy = -149.818675825077
# converged SCF energy = -149.860425677439
# converged SCF energy = -149.861548085144
# converged SCF energy = -149.860256462223
# converged SCF energy = -149.860273417665
# converged SCF energy = -149.86080840329
# converged SCF energy = -149.858582036946
# converged SCF energy = -149.860403957346
# converged SCF energy = -149.859503760906
# converged SCF energy = -149.86058228778
# converged SCF energy = -149.860567820665
# converged SCF energy = -149.85863108984
# converged SCF energy = -149.860199600535
# converged SCF energy = -149.861204008434
# converged SCF energy = -149.860360691798
# converged SCF energy = -149.859963953454
# converged SCF energy = -149.860923016726
# converged SCF energy = -149.859660658029
# converged SCF energy = -149.859286094736
# converged SCF energy = -149.860390106983
# converged SCF energy = -149.859941682875
# converged SCF energy = -149.860450298871
# converged SCF energy = -149.860850002034
# converged SCF energy = -149.859982437973
# converged SCF energy = -149.860627851815
# converged SCF energy = -149.859847428681
# converged SCF energy = -149.860376246714
# converged SCF energy = -149.860077865536
# converged SCF energy = -149.8603334713
# converged SCF energy = -149.861413807172
# converged SCF energy = -149.860101511043
# converged SCF energy = -149.861105998686
# converged SCF energy = -149.860477950348
# converged SCF energy = -149.860266104955
# converged SCF energy = -149.860529771294
# converged SCF energy = -149.860077961824
# converged SCF energy = -149.860247953741
# converged SCF energy = -149.860004300037
# converged SCF energy = -149.860045480755
# converged SCF energy = -149.860421602852
# converged SCF energy = -149.859944817316
# converged SCF energy = -149.860491077145
# converged SCF energy = -149.860859825411
# converged SCF energy = -149.860025200815
# converged SCF energy = -149.860278213033
# converged SCF energy = -149.861862784541
# converged SCF energy = -149.860303295877
# converged SCF energy = -149.843558416149
# converged SCF energy = -149.861247894807
# converged SCF energy = -149.859895921505
# converged SCF energy = -148.471221617666
# converged SCF energy = -149.860377495194
# converged SCF energy = -149.860430286686
# converged SCF energy = -149.803029945337
# converged SCF energy = -149.859855548494
# converged SCF energy = -149.861241377245
# converged SCF energy = -149.861547740718
# converged SCF energy = -149.860255518272
# converged SCF energy = -149.860729387806
# converged SCF energy = -149.860130277461
# converged SCF energy = -149.859030492503
# converged SCF energy = -149.8606381564
# converged SCF energy = -149.860488060786
# converged SCF energy = -149.859983930158
# converged SCF energy = -149.860509836386
# converged SCF energy = -149.860000414049
# converged SCF energy = -149.860402642084
# converged SCF energy = -149.860366135022
# converged SCF energy = -149.860260945124
# converged SCF energy = -149.861368520125
# converged SCF energy = -149.860378295812
# converged SCF energy = -149.846572654022
# converged SCF energy = -149.865854585921
# converged SCF energy = -149.860231859635
# converged SCF energy = -149.858023736536
# converged SCF energy = -149.860666974261
# converged SCF energy = -149.860530906318
# converged SCF energy = -149.859340796113
# converged SCF energy = -149.860550187829
# converged SCF energy = -149.860297305987
# converged SCF energy = -149.858993667367
# converged SCF energy = -149.860777164632
# converged SCF energy = -149.860450726878
# converged SCF energy = -149.860009712663
# converged SCF energy = -149.860103692379
# converged SCF energy = -149.860879901711
# converged SCF energy = -149.860478038739
# converged SCF energy = -149.847788705276
# converged SCF energy = -149.861857044644
# converged SCF energy = -149.860276466895
# converged SCF energy = -149.779950671013
# converged SCF energy = -149.860420301891
# converged SCF energy = -149.86091797763
# converged SCF energy = -149.859921780234
# converged SCF energy = -149.86021175745
# converged SCF energy = -149.860422282193
# converged SCF energy = -149.859957413432
# converged SCF energy = -149.860470775378
# converged SCF energy = -149.860561806526
# converged SCF energy = -149.860312227689
# converged SCF energy = -149.860292559435
# converged SCF energy = -149.846220947355
# converged SCF energy = -149.860005622278
# converged SCF energy = -149.860743955552
# converged SCF energy = -149.861475345538
# converged SCF energy = -149.860444846097
# converged SCF energy = -149.860992731322
# converged SCF energy = -149.85985088154
# converged SCF energy = -149.859858230291
# converged SCF energy = -149.860702022379
# converged SCF energy = -149.860050899398
# converged SCF energy = -149.860188951579
# converged SCF energy = -149.860625274829
# converged SCF energy = -149.859496613283
# converged SCF energy = -149.859952638322
# converged SCF energy = -149.860647689764
# converged SCF energy = -149.860524433665
# converged SCF energy = -149.858944757132
# converged SCF energy = -149.859562661053
# converged SCF energy = -149.860336222053
# converged SCF energy = -149.859871894101
# converged SCF energy = -149.860339518588
# converged SCF energy = -149.860403961839
# converged SCF energy = -149.860305862185
# converged SCF energy = -149.86028946867
# converged SCF energy = -149.862194513738
# converged SCF energy = -149.860475356284
# converged SCF energy = -149.857701289669
# converged SCF energy = -149.861484933925
# converged SCF energy = -149.860120337842
# converged SCF energy = -149.856639070437
# converged SCF energy = -149.860264411196
# converged SCF energy = -149.85973770363
# converged SCF energy = -149.860382465946
# converged SCF energy = -149.860155680116
# converged SCF energy = -149.860598919034
# converged SCF energy = -149.860508414758
# converged SCF energy = -149.859812864333
# converged SCF energy = -149.860163118328
# converged SCF energy = -149.86083587314
# converged SCF energy = -149.860076038834
# converged SCF energy = -149.861971309105
# converged SCF energy = -149.860105247252
# converged SCF energy = -149.861301691178
# converged SCF energy = -149.858208365405
# converged SCF energy = -149.860344507112
# converged SCF energy = -149.861019772257
# converged SCF energy = -149.860053234118
# converged SCF energy = -149.860492950123
# converged SCF energy = -149.85979144727
# converged SCF energy = -149.857524667223
# converged SCF energy = -149.860459684874
# converged SCF energy = -149.860078355818
# converged SCF energy = -149.86035430763
# converged SCF energy = -149.860616303273
# converged SCF energy = -149.859724604582
# converged SCF energy = -149.865854585921
# converged SCF energy = -149.865854587902
# converged SCF energy = -149.86585458597
# converged SCF energy = -149.865854586426
# converged SCF energy = -149.865854585921
# converged SCF energy = -149.865854585921
# converged SCF energy = -149.865854585921
# converged SCF energy = -149.866007610678
# converged SCF energy = -149.86593626417
# converged SCF energy = -149.865896920961
# converged SCF energy = -149.865876233274
# converged SCF energy = -149.865865581841
# converged SCF energy = -149.86586015163
# converged SCF energy = -149.865857401313
# converged SCF energy = -149.865856007051
# converged SCF energy = -149.865855303544
# converged SCF energy = -149.865854950303
# converged SCF energy = -149.865854771058
# converged SCF energy = -149.863679926946
# converged SCF energy = -149.863679925113
# converged SCF energy = -149.863679927297
# converged SCF energy = -149.8636799261
# converged SCF energy = -149.863679926946
# converged SCF energy = -149.863679926946
# converged SCF energy = -149.863679926946
# converged SCF energy = -149.863606391149
# converged SCF energy = -149.863646140357
# converged SCF energy = -149.863663817398
# converged SCF energy = -149.863672081303
# converged SCF energy = -149.863676062695
# converged SCF energy = -149.863678012289
# converged SCF energy = -149.863678973522
# converged SCF energy = -149.863679452794
# converged SCF energy = -149.863679688567
# converged SCF energy = -149.863679807238
# converged SCF energy = -149.863679867625
# converged SCF energy = -149.861971309105
# converged SCF energy = -149.861971307951
# converged SCF energy = -149.861971308734
# converged SCF energy = -149.861971309123
# converged SCF energy = -149.861971309105
# converged SCF energy = -149.861971309104
# converged SCF energy = -149.861971309104
# converged SCF energy = -149.862027767805
# converged SCF energy = -149.862000086118
# converged SCF energy = -149.861985892248
# converged SCF energy = -149.861978678773
# converged SCF energy = -149.86197502938
# converged SCF energy = -149.861973187422
# converged SCF energy = -149.861972256472
# converged SCF energy = -149.861971783942
# converged SCF energy = -149.861971547354
# converged SCF energy = -149.861971430345
# converged SCF energy = -149.86197137007
# converged SCF energy = -149.861475345538
# converged SCF energy = -149.861475346474
# converged SCF energy = -149.861475345199
# converged SCF energy = -149.86147534561
# converged SCF energy = -149.861475345538
# converged SCF energy = -149.861475345538
# converged SCF energy = -149.861475345538
# converged SCF energy = -149.861824116487
# converged SCF energy = -149.861665550299
# converged SCF energy = -149.861578797214
# converged SCF energy = -149.861531546583
# converged SCF energy = -149.861505860826
# converged SCF energy = -149.861491910542
# converged SCF energy = -149.861484335224
# converged SCF energy = -149.861480225201
# converged SCF energy = -149.861477994068
# converged SCF energy = -149.861476782076
# converged SCF energy = -149.861476127996
# converged SCF energy = -149.862194513739
# converged SCF energy = -149.86219451374
# converged SCF energy = -149.862194513895
# converged SCF energy = -149.86219451374
# converged SCF energy = -149.862194513739
# converged SCF energy = -149.862194513738
# converged SCF energy = -149.862194513738
# converged SCF energy = -149.862186757332
# converged SCF energy = -149.862190884898
# converged SCF energy = -149.86219281866
# converged SCF energy = -149.862193719671
# converged SCF energy = -149.862194143955
# converged SCF energy = -149.862194341101
# converged SCF energy = -149.862194433219
# converged SCF energy = -149.862194476065
# converged SCF energy = -149.862194496219
# converged SCF energy = -149.862194505711
# converged SCF energy = -149.862194509971
# converged SCF energy = -149.865761776354
# converged SCF energy = -149.865761776861
# converged SCF energy = -149.865761776347
# converged SCF energy = -149.86576177633
# converged SCF energy = -149.865761776793
# converged SCF energy = -149.865761776355
# converged SCF energy = -149.865761776355
# converged SCF energy = -149.865881425168
# converged SCF energy = -149.865825916528
# converged SCF energy = -149.865796031623
# converged SCF energy = -149.865780036891
# converged SCF energy = -149.865771499721
# converged SCF energy = -149.865766951731
# converged SCF energy = -149.865764530666
# converged SCF energy = -149.865763240519
# converged SCF energy = -149.865762557158
# converged SCF energy = -149.865762190663
# converged SCF energy = -149.865761998013
# <div id="3dmolviewer_2911691931267"  style="position: relative; width: 1000px; height: 700px">
#         <p id="3dmolwarning_2911691931267" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_2911691931267 = null;
# var warn = document.getElementById("3dmolwarning_2911691931267");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_2911691931267 = $3Dmol.createViewer($("#3dmolviewer_2911691931267"),{backgroundColor:"white"});
# viewer_2911691931267.zoomTo();
# 	viewer_2911691931267.addModelsAsFrames("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t-5.62500000\t-5.62500000\t-6.12500000\nH\t-5.03792000\t-4.86746000\t-6.12500000\nH\t-6.21208000\t-4.86746000\t-6.12500000\n\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t-0.00000000\t 0.00000000\t-0.50000000\nH\t 0.00000000\t 0.75754000\t 0.08708000\nH\t 0.00000000\t 0.75754000\t-1.08708000\n\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t 2.77011308\t-2.80008516\t 2.32491484\nH\t 3.44242308\t-2.23946020\t 2.71507980\nH\t 2.85534308\t-2.06750845\t 1.71287155\n\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t-2.77011308\t 2.82491484\t-3.32491484\nH\t-2.85534308\t 3.55749155\t-2.71287155\nH\t-3.44242308\t 3.38553980\t-3.71507980\n\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t-1.43622208\t-1.39858611\t 0.92475226\nH\t-0.66728712\t-0.83766347\t 1.03715597\nH\t-1.66949537\t-0.58139792\t 0.48167573\n\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t 4.24872208\t 4.22425800\t-4.72103149\nH\t 4.06686712\t 4.94837832\t-4.12010860\nH\t 3.89491537\t 4.91677856\t-5.28117956\n\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t 1.37627792\t-4.21324200\t-1.90396851\nH\t 1.73008463\t-3.52072144\t-1.34382044\nH\t 1.55813288\t-3.48912168\t-2.50489140\n\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t-4.18877792\t 1.41391389\t 3.70024774\nH\t-3.95550463\t 2.23110208\t 4.14332427\nH\t-4.95771288\t 1.97483653\t 3.58784403\n\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t-3.47646459\t-2.09949782\t-2.61597472\nH\t-3.64519534\t-1.38451569\t-2.00045846\nH\t-4.00760955\t-1.47592509\t-3.11354065\n\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t 2.07021459\t 3.52725401\t 3.03302905\nH\t 2.82602534\t 4.06034961\t 3.28420426\nH\t 2.01427955\t 4.30140440\t 2.47080825\n\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t 4.93809577\t-4.91927795\t 0.19006874\nH\t 5.35788237\t-4.09452739\t 0.43925845\nH\t 4.22841117\t-4.27536306\t 0.17422075\n\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t-0.71934577\t 0.70469191\t-5.42156332\nH\t-0.55205237\t 1.44607155\t-4.83769782\nH\t-0.59674117\t 1.45038844\t-6.01099914\n\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t-2.09315423\t ...
# [[ -0.61509245  -3.0761684    0.96683307  12.65625     14.765625
#   136.40625   ]
#  [ -1.7577509    2.46093664   1.0546845  118.12505332   2.81250001
#   106.87500001]
#  [ -0.17589735   3.69142847   0.52729015 160.3125      35.15625
#    59.0625    ]
#  [  2.76855472   2.8564505    0.21972662  59.765625    74.1796875
#    89.296875  ]
#  [  1.7137847    2.50485634  -1.5380846   42.890625    54.49218749
#    27.42187499]
#  [ -0.21958772  -2.24126125   2.15333095 130.078125    78.39843748
#   148.35937499]] [-149.86585477 -149.865762   -149.86367987 -149.86219451 -149.86197137
#  -149.86147613]

# %%
#### Testing random moves inside sphere
total_steps = 30

cluster_of_interest = Molecule(
    water,
    water,
    water,
    water
)

#All fragments will be moved AND rotated
serie_of_interest_xyz = ""

for i in range(total_steps):
    serie_of_interest_xyz += random_move(cluster_of_interest).xyz

visualization_random_process(serie_of_interest_xyz,cluster_of_interest.total_atoms)

# %%
# AMCESS test

cluster_of_interest = Molecule(
    water,
    water
)

#Armo la configuración inicial para los fragmentos,
#a partir de la cual se efectúan rotaciones y traslaciones
#No pueden estar juntos inicialmente: el SCF saldría con error

delta=0.5
variaciones=[0,-delta,delta]

i,j,k = 0, 0, 0

for A in range(cluster_of_interest.total_fragments):
    cluster_of_interest = cluster_of_interest.translate(0, x=variaciones[i], y=variaciones[j], z=variaciones[k])
    if ((A+1) % 3 == 0):
            k=0
            if ((A+1) % 9 == 0):
                    j=0
                    if ((A+1) % 27 == 0):
                        i=0
                        print("STOP. For",cluster_of_interest.total_fragments,"or more fragments this should be revised")
                        break
                    else:
                        i=i+1
            else:
                    j=j+1
    else:
            k=k+1


serie_of_interest_xyz_last = "" # Variable global...
minimos = optimization_juan_outer(cluster_of_interest)

#Ploteo todos los puntos donde se evaluó la energía
visualization_random_process(serie_of_interest_xyz_last,cluster_of_interest.total_atoms)


print(minimos.xl, minimos.funl)

# %%
candidates=[]
candidates_coord=[]


for i in range(len(minimos.xl)):

    desplazamientos = [ np.zeros(3) ]
    rotaciones = [ np.zeros(3) ]

    desplazamientos.append(minimos.xl[i][0:3])

    rotaciones.append(minimos.xl[i][3:6])

    #print(desplazamientos,rotaciones)

    
    retrieved_candidated = controled_move(cluster_of_interest, desplazamientos, rotaciones)


    candidates.append(retrieved_candidated)
    candidates_coord.append(retrieved_candidated.cartesian_coordinates)

#Elimino candidatos que sean iguales (coordenadas todas muy parecidas)
for i in range(len(minimos.xl)-1):

    for k in range(i+1,len(candidates)):
            if np.all(np.isclose(candidates[i].cartesian_coordinates, candidates[k].cartesian_coordinates,atol=0.05)):
                    candidates = np.delete(candidates,[k]) #valores muy cercanos

            else:
                    pass

# %%
#Save results on file

#Clean file
with open('water.xyz', 'w') as f:
                f.write(" ")


for i in range(len(candidates)):
        mol = gto.Mole()
        mol.fromstring(str(candidates[i]))
        mol.build()

        mf = scf.RHF(mol)
        mf.kernel()
        energia = mf.energy_tot()


        with open('water.xyz', 'a') as f:

                f.write("---------------    Candidate %.0f    ---------------\n" % int(i+1))
                f.write(str(candidates[i]))
                f.write("Energy: %.6f \n" % mf.energy_tot())
# Out:
# converged SCF energy = -149.865854771058
# converged SCF energy = -149.865761998013
# converged SCF energy = -149.863679867625
# converged SCF energy = -149.862194509971
# converged SCF energy = -149.86197137007
# converged SCF energy = -149.861476127996

# %%
## See Final molecule.

import py3Dmol

for i in range(len(candidates)):
    xyz_view = py3Dmol.view(width=300,height=200)
    xyz_view.addModel(str(candidates[i]),'xyz')
    xyz_view.setStyle({'stick':{}})

    xyz_view.zoomTo()
    xyz_view.show()
# Out:
# <div id="3dmolviewer_5635626699553"  style="position: relative; width: 300px; height: 200px">
#         <p id="3dmolwarning_5635626699553" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_5635626699553 = null;
# var warn = document.getElementById("3dmolwarning_5635626699553");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_5635626699553 = $3Dmol.createViewer($("#3dmolviewer_5635626699553"),{backgroundColor:"white"});
# viewer_5635626699553.zoomTo();
# 	viewer_5635626699553.addModel("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t-0.63321519\t-3.07299045\t 0.48098510\nH\t 0.08762687\t-2.44185492\t 0.50516043\nH\t-1.03016717\t-2.24584227\t 0.20388440\n","xyz");
# 	viewer_5635626699553.setStyle({"stick": {}});
# 	viewer_5635626699553.zoomTo();
# viewer_5635626699553.render();
# });
# </script>
# <div id="3dmolviewer_5635628016339"  style="position: relative; width: 300px; height: 200px">
#         <p id="3dmolwarning_5635628016339" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_5635628016339 = null;
# var warn = document.getElementById("3dmolwarning_5635628016339");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_5635628016339 = $3Dmol.createViewer($("#3dmolviewer_5635628016339"),{backgroundColor:"white"});
# viewer_5635628016339.zoomTo();
# 	viewer_5635628016339.addModel("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t-1.72250742\t 2.46872228\t 0.55052297\nH\t-1.90698519\t 3.18550928\t 1.15938596\nH\t-2.16790193\t 3.12787013\t 0.01603479\n","xyz");
# 	viewer_5635628016339.setStyle({"stick": {}});
# 	viewer_5635628016339.zoomTo();
# viewer_5635628016339.render();
# });
# </script>
# <div id="3dmolviewer_5635629050012"  style="position: relative; width: 300px; height: 200px">
#         <p id="3dmolwarning_5635629050012" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_5635629050012 = null;
# var warn = document.getElementById("3dmolwarning_5635629050012");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_5635629050012 = $3Dmol.createViewer($("#3dmolviewer_5635629050012"),{backgroundColor:"white"});
# viewer_5635629050012.zoomTo();
# 	viewer_5635629050012.addModel("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t-0.14900738\t 3.69780851\t 0.00945913\nH\t 0.13115297\t 4.52182064\t 0.41076196\nH\t-0.90974601\t 4.27485216\t-0.07316736\n","xyz");
# 	viewer_5635629050012.setStyle({"stick": {}});
# 	viewer_5635629050012.zoomTo();
# viewer_5635629050012.render();
# });
# </script>
# <div id="3dmolviewer_563562986362"  style="position: relative; width: 300px; height: 200px">
#         <p id="3dmolwarning_563562986362" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_563562986362 = null;
# var warn = document.getElementById("3dmolwarning_563562986362");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_563562986362 = $3Dmol.createViewer($("#3dmolviewer_563562986362"),{backgroundColor:"white"});
# viewer_563562986362.zoomTo();
# 	viewer_563562986362.addModel("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t 2.73167441\t 2.86505821\t-0.27525666\nH\t 3.21009193\t 3.51093756\t 0.24674557\nH\t 2.91238260\t 3.58042168\t-0.88691788\n","xyz");
# 	viewer_563562986362.setStyle({"stick": {}});
# 	viewer_563562986362.zoomTo();
# viewer_563562986362.render();
# });
# </script>
# <div id="3dmolviewer_5635630497633"  style="position: relative; width: 300px; height: 200px">
#         <p id="3dmolwarning_5635630497633" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_5635630497633 = null;
# var warn = document.getElementById("3dmolwarning_5635630497633");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_5635630497633 = $3Dmol.createViewer($("#3dmolviewer_5635630497633"),{backgroundColor:"white"});
# viewer_5635630497633.zoomTo();
# 	viewer_5635630497633.addModel("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t 1.67151263\t 2.51739873\t-2.02458295\nH\t 2.36439048\t 3.06935738\t-1.65880744\nH\t 1.73412219\t 3.25636207\t-2.63166038\n","xyz");
# 	viewer_5635630497633.setStyle({"stick": {}});
# 	viewer_5635630497633.zoomTo();
# viewer_5635630497633.render();
# });
# </script>
# <div id="3dmolviewer_5635631075964"  style="position: relative; width: 300px; height: 200px">
#         <p id="3dmolwarning_5635631075964" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_5635631075964 = null;
# var warn = document.getElementById("3dmolwarning_5635631075964");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_5635631075964 = $3Dmol.createViewer($("#3dmolviewer_5635631075964"),{backgroundColor:"white"});
# viewer_5635631075964.zoomTo();
# 	viewer_5635631075964.addModel("\t6\n--system of 2 molecules and 6 total individual atoms--\nO\t 0.00000000\t 0.00000000\t 0.00000000\nH\t 0.58708000\t 0.75754000\t 0.00000000\nH\t-0.58708000\t 0.75754000\t 0.00000000\nO\t-0.17782484\t-2.22960569\t 1.64352366\nH\t-0.30766260\t-1.50830198\t 2.26109382\nH\t-0.79437430\t-1.64413788\t 1.20122965\n","xyz");
# 	viewer_5635631075964.setStyle({"stick": {}});
# 	viewer_5635631075964.zoomTo();
# viewer_5635631075964.render();
# });
# </script>

# %%
# Atomic Simulation Environment
# https://wiki.fysik.dtu.dk/ase/index.html
# !pip install --upgrade --user ase


# ChemML
# https://hachmannlab.github.io/chemml/index.html
# !pip install chemml

# %%
# NGLview
# https://github.com/nglviewer/nglview
# !pip install nglview

# ---------------------------------------
# pytraj 
# https://amber-md.github.io/pytraj/latest/index.html
# !pip install pytraj
