# %%
# creating the path (PYTHONPATH) to our module.
# assuming that our 'amcess' directory is out ('..') of our current directory 
import os
import sys
module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# importing de Molecule and Cluster class
from amcess.molecule import Molecule
from amcess.cluster import Cluster

# %% [markdown]
# # Building Cluster Object

# %%
water = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
c_1w = Cluster(water)
c_1w
# Out:
# Cluster(_atoms=[('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
water1 = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
water2 = [("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 1), ("H", -0.58708 + 2.5, 0.75754, 0)]
c_2w = Cluster(water1, water2)
c_2w
# Out:
# Cluster(_atoms=[('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0), ('O', 2.5, 0.0, 0.0), ('H', 3.08708, 0.75754, 1.0), ('H', 1.91292, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
water = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
c_3w = Cluster(3 * water)
c_3w
# Out:
# Cluster(_atoms=[('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0), ('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0), ('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
c_3w = Cluster(water + water + water)
c_3w
# Out:
# Cluster(_atoms=[('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0), ('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0), ('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
water = {"atoms":[("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)] }
c_1w = Cluster(water)
c_1w
# Out:
# Cluster(_atoms=[('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = {"atoms":[("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)] }
w2 = {"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 1), ("H", -0.58708 + 2.5, 0.75754, 0)]}
c_2w = Cluster(w1,w2)
c_2w
# Out:
# Cluster(_atoms=[('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0), ('O', 2.5, 0.0, 0.0), ('H', 3.08708, 0.75754, 1.0), ('H', 1.91292, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
w2 = {"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 1), ("H", -0.58708 + 2.5, 0.75754, 0)]}
c_2w = Cluster(w1,w2)
c_2w
# Out:
# Cluster(_atoms=[('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0), ('O', 2.5, 0.0, 0.0), ('H', 3.08708, 0.75754, 1.0), ('H', 1.91292, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
water = Molecule({"atoms":[("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]})
c_1w = Cluster(water)
c_1w
# Out:
# Cluster(_atoms=[('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = Molecule([("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)])
w2 = Molecule({"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]})
c_2w = Cluster(w1,w2)
c_2w
# Out:
# Cluster(_atoms=[('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0), ('O', 2.5, 0.0, 0.0), ('H', 3.08708, 0.75754, 0.0), ('H', 1.91292, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = Molecule([("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)])
w2 = Molecule({"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]})
c_2w = Cluster(w1+w2)
c_2w
# Out:
# Cluster(_atoms=[('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0), ('O', 2.5, 0.0, 0.0), ('H', 3.08708, 0.75754, 0.0), ('H', 1.91292, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = Molecule([("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)])
w2 = {"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]}
w3 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
c_3w = Cluster(w1,w2,w3)
c_3w
# Out:
# Cluster(_atoms=[('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0), ('O', 2.5, 0.0, 0.0), ('H', 3.08708, 0.75754, 0.0), ('H', 1.91292, 0.75754, 0.0), ('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = Molecule({"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]})
w2 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
c_2w = Cluster(w1+Molecule(w2))
c_2w
# Out:
# Cluster(_atoms=[('O', 2.5, 0.0, 0.0), ('H', 3.08708, 0.75754, 0.0), ('H', 1.91292, 0.75754, 0.0), ('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = Molecule({"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]})
w2 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
c_2w = Cluster(w1+Molecule(w2))
dimer = Cluster(c_2w)
dimer
# Out:
# Cluster(_atoms=[('O', 2.5, 0.0, 0.0), ('H', 3.08708, 0.75754, 0.0), ('H', 1.91292, 0.75754, 0.0), ('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w1 = Molecule({"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]})
w2 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
w3 = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
c_3w = Cluster(w1+Molecule(w2),w3)
trimer = Cluster(c_3w)
trimer
# Out:
# Cluster(_atoms=[('O', 2.5, 0.0, 0.0), ('H', 3.08708, 0.75754, 0.0), ('H', 1.91292, 0.75754, 0.0), ('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0), ('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %% [markdown]
# # Check Methods Now
# Vale la pena tener Get y Set cuando las variables ya son atributos del objeto, como pasa con _seed, _sphere_ceter, ...

# %%
w1 = Molecule({"atoms":[("O", 2.5, 0, 0), ("H", 2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 + 2.5, 0.75754, 0)]})
w2 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
c_2w = Cluster(w1,Molecule(w2))
print(f"Dictionary print:\n {c_2w.GetClusterDict}")
print(f"Freeze molecule: {c_2w.GetFreezeMol}  {c_2w._freeze_molecule}")
c_2w.SetFreezeMol = 2
print(f"Freeze molecule: {c_2w.GetFreezeMol}  {c_2w._freeze_molecule}")
c_2w.SetSeed = 9212
print(f"Random Generator: {c_2w.GetRandomGen}")
print(f"Sphere Center: {c_2w.GetSphereCenter}")
c_2w.SetSphereR = 3.
print(f"Sphere Radios: {c_2w.GetSphereR}")
print(f"Total Molecules: {c_2w.GetTotalMol}")
# Out:
# Dictionary print:
#  {0: Molecule(_atoms={'atoms': [('O', 2.5, 0, 0), ('H', 3.0870800000000003, 0.75754, 0), ('H', 1.91292, 0.75754, 0)]}, _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False), 1: Molecule(_atoms=[('O', -2.5, 0, 0), ('H', -1.91292, 0.75754, 0), ('H', -3.0870800000000003, 0.75754, 0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)}
# Freeze molecule: []  []
# Freeze molecule: [2]  [2]
# Random Generator: Generator(PCG64)
# Sphere Center: (0, 0, 0)
# Sphere Radios: 3.0
# Total Molecules: 2

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print("Molecules are overlapping:"
      f"{dimer.Overlapping(dimer.GetClusterDict[0].GetAtomicCoordinates, dimer.GetClusterDict[1].GetAtomicCoordinates)}"
      )
print(f"Molecule 1: \n{dimer.GetMol(0)}")
print(f"Molecule 2: \n{dimer.GetMol(1)}")
dimer
# Out:
# Molecules are overlapping:True
# Molecule 1:
# Cluster of (1) molecules and (3) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Molecule 2:
# Cluster of (1) molecules and (3) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
# Cluster(_atoms=[('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0), ('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(dimer)
dimer = dimer.TranslateMol(0, x = 1)
print(dimer)
dimer
# Out:
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -1.5, 0.0, 0.0), ('H', -0.91292, 0.75754, 0.0), ('H', -2.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
# Cluster(_atoms=[('O', -1.5, 0.0, 0.0), ('H', -0.91292, 0.75754, 0.0), ('H', -2.08708, 0.75754, 0.0), ('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(dimer)
#! Why rotate asks by coordinates instead by angle
dimer = dimer.RotateMol(0,1)
print(dimer)
dimer
# Out:
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 1.291e-05, 0.00147951), ('H', -1.91292, 0.75743753, -0.01174139), ('H', -3.08708, 0.75743753, -0.01174139)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
# Cluster(_atoms=[('O', -2.5, 1.291e-05, 0.00147951), ('H', -1.91292, 0.75743753, -0.01174139), ('H', -3.08708, 0.75743753, -0.01174139), ('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(dimer)
dimer = dimer.RemoveMol(1)
print(dimer)
dimer
# Out:
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (1) molecules and (3) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
# Cluster(_atoms=[('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
trimer = Cluster(w,w,w)
print(trimer)
trimer = trimer.RemoveMol(1)
print(trimer)
trimer
# Out:
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
# Cluster(_atoms=[('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0), ('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(dimer)
dimer = dimer.InitializeCluster()
print(dimer)
dimer
# Out:
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.28209186, -0.74351618, -1.5377501), ('H', -1.58513483, -0.45358833, -2.12827742), ('H', -2.54815375, 0.13674274, -1.80772246)]
#      --> charge: +0
#      --> multiplicity: 1
# Cluster(_atoms=[('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0), ('O', -2.28209186, -0.74351618, -1.5377501), ('H', -1.58513483, -0.45358833, -2.12827742), ('H', -2.54815375, 0.13674274, -1.80772246)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
trimer = Cluster(w,w,w)
print(trimer)
trimer = trimer.InitializeCluster()
print(trimer)
trimer
# Out:
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.07476834, -0.55082459, -0.85626409), ('H', -1.33913144, -0.22907798, -1.37956825), ('H', -2.24258544, 0.38778884, -0.95307335)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 3 atoms:
#      --> atoms: [('O', -3.78118552, 0.16342918, 0.88435386), ('H', -3.36054688, 0.85740798, 1.39424241), ('H', -4.48999849, 0.77696695, 1.08356571)]
#      --> charge: +0
#      --> multiplicity: 1
# Cluster(_atoms=[('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0), ('O', -2.07476834, -0.55082459, -0.85626409), ('H', -1.33913144, -0.22907798, -1.37956825), ('H', -2.24258544, 0.38778884, -0.95307335), ('O', -3.78118552, 0.16342918, 0.88435386), ('H', -3.36054688, 0.85740798, 1.39424241), ('H', -4.48999849, 0.77696695, 1.08356571)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(dimer)
dimer = dimer.MoveMol(1)
print(dimer)
dimer
# Out:
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -3.58460993, 0.207054, -2.10412946), ('H', -2.78140443, 0.66933066, -1.85981206), ('H', -3.8312692, 1.13316325, -2.10739032)]
#      --> charge: +0
#      --> multiplicity: 1
# Cluster(_atoms=[('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0), ('O', -3.58460993, 0.207054, -2.10412946), ('H', -2.78140443, 0.66933066, -1.85981206), ('H', -3.8312692, 1.13316325, -2.10739032)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
trimer = Cluster(w,w,w)
print(trimer)
trimer = trimer.MoveMol(1)
print(trimer)
trimer
# Out:
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 3 atoms:
#      --> atoms: [('O', -3.88283178, -0.62174641, -0.73885708), ('H', -3.75509336, 0.29606785, -0.98345811), ('H', -4.76712947, -0.25245854, -0.75204201)]
#      --> charge: +0
#      --> multiplicity: 1
# Cluster(_atoms=[('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0), ('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0), ('O', -3.88283178, -0.62174641, -0.73885708), ('H', -3.75509336, 0.29606785, -0.98345811), ('H', -4.76712947, -0.25245854, -0.75204201)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
#! Warning: dimer.CalCentRSphere doesn't update only, it's neccesary dimer = dimer.CalCentRSphere()
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
dimer = Cluster(w,w)
print(dimer)
print(f"Radio: {dimer.GetSphereR} Center: {dimer.GetSphereCenter}\n")
dimer = dimer.CalCentRSphere()
print(dimer)
print(f"Radio: {dimer.GetSphereR} Center: {dimer.GetSphereCenter}")
dimer
# Out:
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Radio: None Center: (0, 0, 0)
#
# Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.12249653, 0.01967299, -1.35870291), ('H', -1.99780998, 0.9362344, -1.60949809), ('H', -3.00492949, 0.39339472, -1.345515)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Radio: 3.315836434569796 Center: (-2.5, 0.08477383513738551, 0.0)
# Cluster(_atoms=[('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0), ('O', -2.12249653, 0.01967299, -1.35870291), ('H', -1.99780998, 0.9362344, -1.60949809), ('H', -3.00492949, 0.39339472, -1.345515)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %%
w = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
trimer = Cluster(w,w,w)
print(trimer)
print(f"Radio: {trimer.GetSphereR} Center: {trimer.GetSphereCenter}\n")
trimer = trimer.CalCentRSphere()
print(trimer)
print(f"Radio: {trimer.GetSphereR} Center: {trimer.GetSphereCenter}")
trimer
# Out:
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Radio: None Center: (0, 0, 0)
#
# Cluster of (3) molecules and (9) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.60613173, 1.48995936, 1.46051216), ('H', -2.46294731, 2.37014662, 1.81165085), ('H', -3.39761234, 1.97456596, 1.22125359)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 3 atoms:
#      --> atoms: [('O', -2.12222659, 1.73328688, -1.17801214), ('H', -1.99521296, 2.65251061, -0.93837693), ('H', -2.86138771, 1.93463988, -0.60214099)]
#      --> charge: +0
#      --> multiplicity: 1
#
# Radio: 4.115111259054715 Center: (-2.5, 0.08477383513738551, 0.0)
# Cluster(_atoms=[('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0), ('O', -2.60613173, 1.48995936, 1.46051216), ('H', -2.46294731, 2.37014662, 1.81165085), ('H', -3.39761234, 1.97456596, 1.22125359), ('O', -2.12222659, 1.73328688, -1.17801214), ('H', -1.99521296, 2.65251061, -0.93837693), ('H', -2.86138771, 1.93463988, -0.60214099)], _charge=0, _multiplicity=1, _file=False, _addHs=False, _removeHs=False)

# %% [markdown]
# # Check Magic Method

# %%
# Decopy produce conflict
w1 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
w2 = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
c = Cluster(w1)
c += w2
print(f"Total Molecules: {c}")
# Out:
# Total Molecules: Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1

# %%
# Decopy produce conflict
w1 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
w2 = [("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)]
c = Cluster(w1)
c1 = c + w2
print(f"Total Molecules: {c1}")
# Out:
# Total Molecules: Cluster of (2) molecules and (6) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', 0.0, 0.0, 0.0), ('H', 0.58708, 0.75754, 0.0), ('H', -0.58708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1

# %%
# Decopy produce conflict
w1 = [("O", -2.5, 0, 0), ("H", -2.5 + 0.58708, 0.75754, 0), ("H", -0.58708 - 2.5, 0.75754, 0)]
c = Cluster(w1)
c *= 3
print(f"Total Molecules: {c}")
# Out:
# Total Molecules: Cluster of (3) molecules and (12) total atoms
#  #0: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #1: molecule with 3 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
#  #2: molecule with 6 atoms:
#      --> atoms: [('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0), ('O', -2.5, 0.0, 0.0), ('H', -1.91292, 0.75754, 0.0), ('H', -3.08708, 0.75754, 0.0)]
#      --> charge: +0
#      --> multiplicity: 1
