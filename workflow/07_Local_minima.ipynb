# %% [markdown]
# # Find local minima of a molecular cluster using
# # shgo and dual_annealing method

# %% [markdown]
# ## The function to be minimized is f(x)=x sin(4*np.pi abs(x-1))

# %%
# crating the path (PYTHONPATH) to our module.
# assuming that our 'amcess' directory is out ('..') of our current directory 
import os
import sys
module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from amcess.local_minima_2 import extra_functions
from amcess.base_molecule import Cluster

HH = [("H", 0, 0, 0), ("H", 1, 0, 0)]
HF = [("H", 3, 0, 0), ("F", 5, 0, 0)]
H3F = Cluster(HH, HF)


H3F_freeze_heavier = extra_functions(initial_cluster=H3F).center_sphere_mass
print(H3F_freeze_heavier.xyz)

print("The minima will be found freezing the first molecule and varying the others")
# Out:
# 	4
# -- charge=0 and multiplicity=1 --
# H     	     3.00000000	     0.00000000	     0.00000000
# F     	     5.00000000	     0.00000000	     0.00000000
# H     	     0.00000000	     0.00000000	     0.00000000
# H     	     1.00000000	     0.00000000	     0.00000000
#
# The minima will be found freezing the first molecule and varying the others

# %%
 #If you want to freeze the molecule with most atoms and the others will be 
# free to move, you can use the following extra_function

HH = [("H", 0, 0, 0), ("H", 1, 0, 0)]
H2O = [("H", 3, 0, 0), ("O", 4, 0, 0),("H", 5, 0, 0)]
molecule = Cluster(HH, H2O)

molecule_freeze_bigest = extra_functions(initial_cluster=molecule).center_sphere_atoms
print(molecule_freeze_bigest.xyz)
# Out:
# 	5
# -- charge=0 and multiplicity=1 --
# H     	     3.00000000	     0.00000000	     0.00000000
# O     	     4.00000000	     0.00000000	     0.00000000
# H     	     5.00000000	     0.00000000	     0.00000000
# H     	     0.00000000	     0.00000000	     0.00000000
# H     	     1.00000000	     0.00000000	     0.00000000

# %%
from amcess.local_minima_2 import LocalMinima

water_molecule=[("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)
    ]

w2 = Cluster(water_molecule, water_molecule)
w2 = w2.initialize_cluster(max_closeness=3)

#in order to find the local minima with the shgo method, 
#you can use the following function from the Method LocalMinima

minima = LocalMinima(initial_cluster=w2, 
tolerance=2, basis="sto-3g", method="hf", 
ordening_cluster="mass").shgo_optimize(sampling_method="halton")

#you can choose the atomic_basis, if you wan to ordenate the cluster by the mass
#or by the size. Also, you can choose some DFT functional, like "b3lyp" or "pbe0"
#in the "method" variable.

#About the tolerance:
# The bounds using in all the optimization methods are the same, 
# and the ratio of bounds (bounds=(-ratio_bounds, ratio_bounds)) are defined as 
# the distance between the center of mass of the Center Molecule (most massive,
# by default) and the center of mass of the other molecules PLUS(+) 
# the tolerance. 
print("The global minima of the Energy Function is",minima.fun)
#print("and their local minima are", minima.funl)

print("Local minima of the Cluster will be generated in a xyz file automatically")
# Out:
# converged SCF energy = -2.02588720404322
# converged SCF energy = -2.02665293088768
# converged SCF energy = -2.0266572744242
# converged SCF energy = -2.02665480301794
# converged SCF energy = -2.02665244094093
# converged SCF energy = -2.02665108433647
# converged SCF energy = -2.02657175955278
# converged SCF energy = -2.02665665560704
# converged SCF energy = -2.02665632787991
# converged SCF energy = -2.02665477586913
# converged SCF energy = -2.02662972727097
# converged SCF energy = -2.02665475800338
# converged SCF energy = -2.02642741637508
# converged SCF energy = -2.02666283123455
# converged SCF energy = -2.02665392342279
# converged SCF energy = -2.02665529011304
# converged SCF energy = -2.02666283123454
# converged SCF energy = -2.02666283123445
# converged SCF energy = -2.02666283082797
# converged SCF energy = -2.02666283241957
# converged SCF energy = -2.02666283123455
# converged SCF energy = -2.02666283123455
# converged SCF energy = -2.02666283123455
# converged SCF energy = -2.02666171579461
# converged SCF energy = -2.02666226840319
# converged SCF energy = -2.02666254892868
# converged SCF energy = -2.02666268913878
# converged SCF energy = -2.02666276088474
# converged SCF energy = -2.02666279683836
# converged SCF energy = -2.0266628142196
# converged SCF energy = -2.02666282352295
# converged SCF energy = -2.02666282637979
# converged SCF energy = -2.02666282901079
# converged SCF energy = -2.02666282839412
# converged SCF energy = -2.02666283130803
# converged SCF energy = -2.02666282798755
# converged SCF energy = -2.02666282720867
# converged SCF energy = -2.02666282839412
# converged SCF energy = -2.02666282839412
# converged SCF energy = -2.02666282839412
# converged SCF energy = -2.026660221505
# converged SCF energy = -2.02666156763732
# converged SCF energy = -2.0266622104547
# converged SCF energy = -2.02666252293579
# converged SCF energy = -2.02666267752616
# converged SCF energy = -2.02666275362531
# converged SCF energy = -2.02666279172641
# converged SCF energy = -2.02666281232877
# converged SCF energy = -2.02666282182301
# converged SCF energy = -2.02666282497509
# converged SCF energy = -2.02666282775278
# converged SCF energy = -2.02666282775269
# converged SCF energy = -2.02666282734621
# converged SCF energy = -2.02666282893781
# converged SCF energy = -2.02666282775278
# converged SCF energy = -2.02666282775278
# converged SCF energy = -2.02666282775278
# converged SCF energy = -2.02665573467358
# converged SCF energy = -2.0266509792958
# converged SCF energy = -2.02664275524908
# converged SCF energy = -2.0266495626439
# converged SCF energy = -2.02665626481699
# converged SCF energy = -2.02665970310082
# converged SCF energy = -2.02666132134072
# converged SCF energy = -2.02666209032946
# converged SCF energy = -2.0266624634966
# converged SCF energy = -2.02666264750996
# converged SCF energy = -2.02666273830907
# converged SCF energy = -2.02666273830897
# converged SCF energy = -2.02666273871562
# converged SCF energy = -2.02666273712361
# converged SCF energy = -2.02666273830907
# converged SCF energy = -2.02666273830907
# converged SCF energy = -2.02666273830907
# converged SCF energy = -2.02666278277238
# converged SCF energy = -2.02666276135784
# converged SCF energy = -2.02666274963659
# converged SCF energy = -2.02666274397499
# converged SCF energy = -2.02666274154938
# converged SCF energy = -2.02666273562708
# converged SCF energy = -2.02666273783222
# converged SCF energy = -2.02666273906977
# converged SCF energy = -2.02666273730099
# converged SCF energy = -2.02666273721228
# converged SCF energy = -2.02666273875973
# converged SCF energy = -2.02666273875963
# converged SCF energy = -2.02666273835316
# converged SCF energy = -2.02666273757427
# converged SCF energy = -2.02666273875973
# converged SCF energy = -2.02666273875973
# converged SCF energy = -2.02666273875973
# converged SCF energy = -2.02666798949085
# converged SCF energy = -2.02666576867201
# converged SCF energy = -2.02666434335939
# converged SCF energy = -2.0266635597865
# converged SCF energy = -2.0266631536448
# converged SCF energy = -2.02666294678751
# converged SCF energy = -2.02666284248309
# converged SCF energy = -2.026662791295
# converged SCF energy = -2.02666276345884
# converged SCF energy = -2.02666275191237
# converged SCF energy = -2.02666274493214
# converged SCF energy = -2.02666274493204
# converged SCF energy = -2.02666274533869
# converged SCF energy = -2.02666274374668
# converged SCF energy = -2.02666274493214
# converged SCF energy = -2.02666274493214
# converged SCF energy = -2.02666274374682
# converged SCF energy = -2.02665283167344
# converged SCF energy = -2.02665470103389
# converged SCF energy = -2.02666667315024
# converged SCF energy = -2.02666937713042
# converged SCF energy = -2.02666724038661
# converged SCF energy = -2.02666524729594
# converged SCF energy = -2.0266640518166
# converged SCF energy = -2.02666340907577
# converged SCF energy = -2.02666307968955
# converged SCF energy = -2.02666291512948
# converged SCF energy = -2.02666282779182
# converged SCF energy = -2.02666282779172
# converged SCF energy = -2.02666282779181
# converged SCF energy = -2.02666282897684
# converged SCF energy = -2.02666282779181
# converged SCF energy = -2.02666282779182
# converged SCF energy = -2.02666282779182
# converged SCF energy = -2.02666278847028
# converged SCF energy = -2.0266628066898
# converged SCF energy = -2.02666281724602
# converged SCF energy = -2.02666282543488
# converged SCF energy = -2.02666282515672
# converged SCF energy = -2.0266628264746
# converged SCF energy = -2.02666283123261
# converged SCF energy = -2.02666282824085
# converged SCF energy = -2.02666282762693
# converged SCF energy = -2.02666283180859
# converged SCF energy = -2.02666282775009
# converged SCF energy = -2.02666283066399
# converged SCF energy = -2.02666282775008
# converged SCF energy = -2.02666282893511
# converged SCF energy = -2.02666282775009
# converged SCF energy = -2.02666282775009
# converged SCF energy = -2.02666282775009
# converged SCF energy = -2.02666218651301
# converged SCF energy = -2.02666251015035
# converged SCF energy = -2.02666267103656
# converged SCF energy = -2.02666275180859
# converged SCF energy = -2.02666278816142
# converged SCF energy = -2.02666280796709
# converged SCF energy = -2.02666281786181
# converged SCF energy = -2.02666282280696
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6408/3209187121.py in <module>
#      10 #you can use the following function from the Method LocalMinima
#      11
# ---> 12 minima = LocalMinima(initial_cluster=w2,
#      13 tolerance=2, basis="sto-3g", method="hf",
#      14 ordening_cluster="mass").shgo_optimize(sampling_method="halton")
#
# ~/ascec/amcess/local_minima_2.py in shgo_optimize(self, n, iters, sampling_method)
#     186         energie = self.energy
#     187
# --> 188         minimos = shgo(
#     189             energie,
#     190             bounds=self.bounds,
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in shgo(func, bounds, args, constraints, n, iters, callback, minimizer_kwargs, options, sampling_method)
#     417
#     418     # Run the algorithm, process results and test success
# --> 419     shc.construct_complex()
#     420
#     421     if not shc.break_routine:
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in construct_complex(self)
#     738         if not self.minimize_every_iter:
#     739             if not self.break_routine:
# --> 740                 self.find_minima()
#     741
#     742         self.res.nit = self.iters_done + 1
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in find_minima(self)
#     752             # Note that if Options['local_iter'] is an `int` instead of default
#     753             # value False then only that number of candidates will be minimized
# --> 754             self.minimise_pool(self.local_iter)
#     755             # Sort results and build the global return object
#     756             self.sort_result()
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in minimise_pool(self, force_iter)
#     976         # NOTE: Since we always minimize this value regardless it is a waste to
#     977         # build the topograph first before minimizing
# --> 978         lres_f_min = self.minimize(self.X_min[0], ind=self.minimizer_pool[0])
#     979
#     980         # Trim minimized point from current minimizer set
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in minimize(self, x_min, ind)
#    1163
#    1164         # Local minimization using scipy.optimize.minimize:
# -> 1165         lres = minimize(self.func, x_min, **self.minimizer_kwargs)
#    1166
#    1167         if self.disp:
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     629         return _minimize_cobyla(fun, x0, args, constraints, **options)
#     630     elif meth == 'slsqp':
# --> 631         return _minimize_slsqp(fun, x0, args, jac, bounds,
#     632                                constraints, callback=callback, **options)
#     633     elif meth == 'trust-constr':
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     431
#     432         if mode == 1:  # objective and constraint evaluation required
# --> 433             fx = wrapped_fun(x)
#     434             c = _eval_constraint(x, cons)
#     435
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/optimize.py in eval(x)
#     273     def eval(x):
#     274         x = _check_clip_x(x, bounds)
# --> 275         return func(x)
#     276
#     277     return eval
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun(self, x)
#     247         if not np.array_equal(x, self.x):
#     248             self._update_x_impl(x)
# --> 249         self._update_fun()
#     250         return self.f
#     251
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     231     def _update_fun(self):
#     232         if not self.f_updated:
# --> 233             self._update_fun_impl()
#     234             self.f_updated = True
#     235
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     135
#     136         def update_fun():
# --> 137             self.f = fun_wrapped(self.x)
#     138
#     139         self._update_fun_impl = update_fun
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# ~/ascec/amcess/electronic_energy_2.py in energy(self, x)
#      75         candidate_to_test = self.controled_move(x)
#      76         mol = gto.Mole()
# ---> 77         mol.fromstring(str(candidate_to_test.xyz))
#      78         mol.build(basis=self.basis)
#      79         if self.method == "hf":
#
# ~/.local/lib/python3.8/site-packages/pyscf/gto/mole.py in fromstring(self, string, format)
#    3199         '''Update the Mole object based on the input geometry string'''
#    3200         atom = self.format_atom(fromstring(string, format), unit=1)
# -> 3201         self.set_geom_(atom, unit='Angstrom', inplace=True)
#    3202         if format == 'sdf' and 'M  CHG' in string:
#    3203             raise NotImplementedError
#
# ~/.local/lib/python3.8/site-packages/pyscf/gto/mole.py in set_geom_(self, atoms_or_coords, unit, symmetry, inplace)
#    2850         else:
#    2851             mol.symmetry = symmetry
# -> 2852             mol.build(False, False)
#    2853
#    2854         if mol.verbose >= logger.INFO:
#
# ~/.local/lib/python3.8/site-packages/pyscf/gto/mole.py in build(self, dump_input, parse_arg, verbose, output, max_memory, atom, basis, unit, nucmod, ecp, charge, spin, symmetry, symmetry_subgroup, cart)
#    2288
#    2289         '''
# -> 2290         gc.collect()  # To release circular referred objects
#    2291
#    2292         if isinstance(dump_input, (str, unicode)):
#
# KeyboardInterrupt:

# %%
#The dual annealing method will obtain several local minima of the molecular cluster.
# The number of local minima will grow up with the number of runs "num_runs"
minima = LocalMinima(initial_cluster=w2).dual_annealing_optimize(num_runs=2)

#the clusters in the local minima will be saved in a xyz file automatically.
# Out:
# converged SCF energy = -149.860189123306
# converged SCF energy = -149.860374685254
# 0
# converged SCF energy = -149.860438878608
# 0
# converged SCF energy = -149.860426095611
# converged SCF energy = -149.860506021004
# 0
# converged SCF energy = -149.860399061471
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_57371/524318217.py in <module>
#       1 #The dual annealing method will obtain several local minima of the molecular cluster.
#       2 # The number of local minima will grow up with the number of runs "num_runs"
# ----> 3 minima = LocalMinima(initial_cluster=w2).dual_annealing_optimize(num_runs=2)
#       4
#       5 #the clusters in the local minima will be saved in a xyz file automatically.
#
# ~/ascec/amcess/local_minima_2.py in dual_annealing_optimize(self, num_runs, maxiter)
#     233         for i in range(num_runs):
#     234             energie = self.energy
# --> 235             minimo = dual_annealing(
#     236                 energie,
#     237                 bounds=self.bounds,
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_dual_annealing.py in dual_annealing(func, bounds, args, maxiter, local_search_options, initial_temp, restart_temp_ratio, visit, accept, maxfun, seed, no_local_search, callback, x0)
#     673                 break
#     674             # starting strategy chain
# --> 675             val = strategy_chain.run(i, temperature)
#     676             if val is not None:
#     677                 message.append(val)
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_dual_annealing.py in run(self, step, temperature)
#     295                 self.energy_state.current_location, j, temperature)
#     296             # Calling the objective function
# --> 297             e = self.func_wrapper.fun(x_visit)
#     298             if e < self.energy_state.current_energy:
#     299                 # We have got a better energy value
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_dual_annealing.py in fun(self, x)
#     378     def fun(self, x):
#     379         self.nfev += 1
# --> 380         return self.func(x, *self.args)
#     381
#     382
#
# ~/ascec/amcess/electronic_energy_2.py in energy(self, x)
#      88             mf.conv_tol_grad = 1e-10
#      89             mf.max_cycle = 200
# ---> 90         mf.kernel()
#      91         return mf.energy_tot()
#
# ~/.local/lib/python3.8/site-packages/pyscf/lib/misc.py in aliased_fn(self, *args, **kwargs)
#     634     fname = fn.__name__
#     635     def aliased_fn(self, *args, **kwargs):
# --> 636         return getattr(self, fname)(*args, **kwargs)
#     637
#     638     if alias_name is not None:
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in scf(self, dm0, **kwargs)
#    1646             self.converged, self.e_tot, \
#    1647                     self.mo_energy, self.mo_coeff, self.mo_occ = \
# -> 1648                     kernel(self, self.conv_tol, self.conv_tol_grad,
#    1649                            dm0=dm0, callback=self.callback,
#    1650                            conv_check=self.conv_check, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in kernel(mf, conv_tol, conv_tol_grad, dump_chk, dm0, callback, conv_check, **kwargs)
#     175         # attach mo_coeff and mo_occ to dm to improve DFT get_veff efficiency
#     176         dm = lib.tag_array(dm, mo_coeff=mo_coeff, mo_occ=mo_occ)
# --> 177         vhf = mf.get_veff(mol, dm, dm_last, vhf)
#     178         e_tot = mf.energy_tot(dm, h1e, vhf)
#     179
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in get_veff(self, mol, dm, dm_last, vhf_last, hermi)
#    1964         if dm is None: dm = self.make_rdm1()
#    1965         if self._eri is not None or not self.direct_scf:
# -> 1966             vj, vk = self.get_jk(mol, dm, hermi)
#    1967             vhf = vj - vk * .5
#    1968         else:
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in get_jk(self, mol, dm, hermi, with_j, with_k, omega)
#    1954             if self._eri is None:
#    1955                 self._eri = mol.intor('int2e', aosym='s8')
# -> 1956             vj, vk = dot_eri_dm(self._eri, dm, hermi, with_j, with_k)
#    1957         else:
#    1958             vj, vk = SCF.get_jk(self, mol, dm, hermi, with_j, with_k, omega)
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in dot_eri_dm(eri, dm, hermi, with_j, with_k)
#     716             vk = vk.reshape(dm.shape)
#     717     else:
# --> 718         vj, vk = _vhf.incore(eri, dm.real, hermi, with_j, with_k)
#     719         if dm.dtype == numpy.complex128:
#     720             vs = _vhf.incore(eri, dm.imag, 0, with_j, with_k)
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/_vhf.py in incore(eri, dms, hermi, with_j, with_k)
#     211         if with_j:
#     212             fvj = _fpointer('CVHFics8_tridm_vj')
# --> 213             tridms = lib.pack_tril(lib.hermi_sum(dms, axes=(0,2,1)))
#     214             idx = numpy.arange(nao)
#     215             tridms[:,idx*(idx+1)//2+idx] *= .5
#
# ~/.local/lib/python3.8/site-packages/pyscf/lib/numpy_helper.py in pack_tril(mat, axis, out)
#     290             return out
#     291
# --> 292         fn(ctypes.c_int(count), ctypes.c_int(nd),
#     293            out.ctypes.data_as(ctypes.c_void_p),
#     294            mat.ctypes.data_as(ctypes.c_void_p))
#
# KeyboardInterrupt:
