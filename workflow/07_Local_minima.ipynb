# %% [markdown]
# # Find global (and local) minima of molecular clusters
# # using the shgo, dual_annealing and gaussian process method

# %%
# crating the path (PYTHONPATH) to our module.
# assuming that our 'amcess' directory is out ('..') of our current directory 
import os
import sys
module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from amcess.local_minima_2 import extra_functions
from amcess.base_molecule import Cluster

HH = [("H", 0, 0, 0), ("H", 1, 0, 0)]
HF = [("H", 3, 0, 0), ("F", 5, 0, 0)]
H3F = Cluster(HH, HF)


H3F_freeze_heavier = extra_functions(initial_cluster=H3F).center_sphere_mass
print(H3F_freeze_heavier.xyz)

print("The minima will be found freezing the first molecule and varying the others")
# Out:
# 	4
# -- charge=0 and multiplicity=1 --
# H     	     3.00000000	     0.00000000	     0.00000000
# F     	     5.00000000	     0.00000000	     0.00000000
# H     	     0.00000000	     0.00000000	     0.00000000
# H     	     1.00000000	     0.00000000	     0.00000000
#
# The minima will be found freezing the first molecule and varying the others

# %%
#If you want to freeze the molecule with most atoms and the others will be 
# free to move, you can use the following extra_function

HH = [("H", 0, 0, 0), ("H", 1, 0, 0)]
H2O = [("H", 3, 0, 0), ("O", 4, 0, 0),("H", 5, 0, 0)]
molecule = Cluster(HH, H2O)

molecule_freeze_bigest = extra_functions(initial_cluster=molecule).center_sphere_atoms
print(molecule_freeze_bigest.xyz)
# Out:
# 	5
# -- charge=0 and multiplicity=1 --
# H     	     3.00000000	     0.00000000	     0.00000000
# O     	     4.00000000	     0.00000000	     0.00000000
# H     	     5.00000000	     0.00000000	     0.00000000
# H     	     0.00000000	     0.00000000	     0.00000000
# H     	     1.00000000	     0.00000000	     0.00000000

# %%
from amcess.local_minima_2 import LocalMinima

water_molecule=[
    ("O", 0, 0, 0), ("H", 0.58708, 0.75754, 0), ("H", -0.58708, 0.75754, 0)
    ]

w2 = Cluster(water_molecule, water_molecule)
w2 = w2.initialize_cluster(max_closeness=3)

#in order to find the local minima with the shgo method, 
#you can use the following function from the Method LocalMinima

minima = LocalMinima(initial_cluster=w2, 
tolerance=2, basis="sto-3g", method="hf", 
ordening_cluster="mass").shgo_optimize()

#you can choose the atomic_basis, if you wan to ordenate the cluster by the mass
#or by the size. Also, you can choose some DFT functional, like "b3lyp" or "pbe0"
#in the "method" variable.

print(minima.fun)
# Out:
# converged SCF energy = -149.860385599148
# converged SCF energy = -149.859605680418
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_28143/2316653390.py in <module>
#      11 #you can use the following function from the Method LocalMinima
#      12
# ---> 13 minima = LocalMinima(initial_cluster=w2,
#      14 tolerance=2, basis="sto-3g", method="hf",
#      15 ordening_cluster="mass").shgo_optimize()
#
# ~/ascec/amcess/local_minima_2.py in shgo_optimize(self, n, iters, sampling_method)
#     158         energie = self.energy
#     159
# --> 160         minimos = shgo(
#     161             energie,
#     162             bounds=self.bounds,
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in shgo(func, bounds, args, constraints, n, iters, callback, minimizer_kwargs, options, sampling_method)
#     419
#     420     # Run the algorithm, process results and test success
# --> 421     shc.construct_complex()
#     422
#     423     if not shc.break_routine:
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in construct_complex(self)
#     724                 break
#     725             # Iterate complex, process minimisers
# --> 726             self.iterate()
#     727             self.stopping_criteria()
#     728
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in iterate(self)
#     867
#     868     def iterate(self):
# --> 869         self.iterate_complex()
#     870
#     871         # Build minimizer pool
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in iterate_delaunay(self)
#     904         """
#     905         self.nc += self.n
# --> 906         self.sampled_surface(infty_cons_sampl=self.infty_cons_sampl)
#     907         self.n_sampled = self.nc
#     908         return
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in sampled_surface(self, infty_cons_sampl)
#    1234
#    1235         # Find objective function references
# -> 1236         self.fun_ref()
#    1237
#    1238         self.n_sampled = self.nc
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py in fun_ref(self)
#    1445
#    1446             if eval_f:
# -> 1447                 self.F[i] = self.func(self.C[i, :], *self.args)
#    1448                 self.fn += 1
#    1449             elif self.infty_cons_sampl:
#
# ~/ascec/amcess/electronic_energy_2.py in energy(self, x)
#      88             mf.conv_tol_grad = 1e-10
#      89             mf.max_cycle = 200
# ---> 90         mf.kernel()
#      91         return mf.energy_tot()
#
# ~/.local/lib/python3.8/site-packages/pyscf/lib/misc.py in aliased_fn(self, *args, **kwargs)
#     634     fname = fn.__name__
#     635     def aliased_fn(self, *args, **kwargs):
# --> 636         return getattr(self, fname)(*args, **kwargs)
#     637
#     638     if alias_name is not None:
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in scf(self, dm0, **kwargs)
#    1646             self.converged, self.e_tot, \
#    1647                     self.mo_energy, self.mo_coeff, self.mo_occ = \
# -> 1648                     kernel(self, self.conv_tol, self.conv_tol_grad,
#    1649                            dm0=dm0, callback=self.callback,
#    1650                            conv_check=self.conv_check, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in kernel(mf, conv_tol, conv_tol_grad, dump_chk, dm0, callback, conv_check, **kwargs)
#     169         last_hf_e = e_tot
#     170
# --> 171         fock = mf.get_fock(h1e, s1e, vhf, dm, cycle, mf_diis)
#     172         mo_energy, mo_coeff = mf.eig(fock, s1e)
#     173         mo_occ = mf.get_occ(mo_energy, mo_coeff)
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in get_fock(mf, h1e, s1e, vhf, dm, cycle, diis, diis_start_cycle, level_shift_factor, damp_factor)
#     902         f = damping(s1e, dm*.5, f, damp_factor)
#     903     if diis is not None and cycle >= diis_start_cycle:
# --> 904         f = diis.update(s1e, dm, f, mf, h1e, vhf)
#     905     if abs(level_shift_factor) > 1e-4:
#     906         f = level_shift(s1e, dm*.5, f, level_shift_factor)
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/diis.py in update(self, s, d, f, *args, **kwargs)
#      47         errvec = get_err_vec(s, d, f)
#      48         logger.debug1(self, 'diis-norm(errvec)=%g', numpy.linalg.norm(errvec))
# ---> 49         xnew = lib.diis.DIIS.update(self, f, xerr=errvec)
#      50         if self.rollback > 0 and len(self._bookkeep) == self.space:
#      51             self._bookkeep = self._bookkeep[-self.rollback:]
#
# ~/.local/lib/python3.8/site-packages/pyscf/lib/diis.py in update(self, x, xerr)
#     232
#     233         if self._xprev is None:
# --> 234             xnew = self.extrapolate(nd)
#     235         else:
#     236             self._xprev = None # release memory first
#
# ~/.local/lib/python3.8/site-packages/pyscf/lib/diis.py in extrapolate(self, nd)
#     252         g[0] = 1
#     253
# --> 254         w, v = scipy.linalg.eigh(h)
#     255         if numpy.any(abs(w)<1e-14):
#     256             logger.debug(self, 'Linear dependence found in DIIS error vectors.')
#
# ~/.local/lib/python3.8/site-packages/scipy/linalg/decomp.py in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, turbo, eigvals, type, check_finite, subset_by_index, subset_by_value, driver)
#     543
#     544         drv_args.update({'lower': lower, 'compute_v': 0 if _job == "N" else 1})
# --> 545         w, v, *other_args, info = drv(a=a1, **drv_args, **lwork_args)
#     546
#     547     else:  # Generalized problem
#
# KeyboardInterrupt:

# %%
#In the shgo_optimize function, you can choose the number of iterations, with "iters", 
# the number of sampling points in the construction of the simplicial complex "n"
# and the sampling method, "sobol" or "simplicial"
minima = LocalMinima(initial_cluster=w2, 
tolerance=2, basis="sto-3g", method="hf", 
ordening_cluster="mass").shgo_optimize(
    sampling_method="sobol", n=1, iters=1)
print(minima.fun)

#the cluster optimized will be save in a file called "configurations.xyz"
# Out:
# converged SCF energy = -149.860385599148
# converged SCF energy = -149.859605680418
# -149.86038559914823

# %%
#the other method you can use in order to find the local minima is the
#dual_annealing method, which is a method that is based on the dual annealing,
#that can be used several times ("") in order to find local minima.

minima = LocalMinima(initial_cluster=w2).dual_annealing_optimize(num_runs=2)
print(minima.fun)

#the clusters optimized will be save in a file called "configurations.xyz"
# Out:
# converged SCF energy = -149.860412105374
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_28143/3906046921.py in <module>
#       3 #that can be used several times ("") in order to find local minima.
#       4
# ----> 5 minima = LocalMinima(initial_cluster=w2).dual_annealing_optimize(num_runs=2)
#       6 print(minima.fun)
#       7
#
# ~/ascec/amcess/local_minima_2.py in dual_annealing_optimize(self, num_runs, maxiter)
#     204         for i in range(num_runs):
#     205             energie = self.energy
# --> 206             minimo = dual_annealing(
#     207                 energie, bounds=self.bounds, maxiter=maxiter
#     208             )
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_dual_annealing.py in dual_annealing(func, bounds, args, maxiter, local_search_options, initial_temp, restart_temp_ratio, visit, accept, maxfun, seed, no_local_search, callback, x0)
#     664                 break
#     665             # starting strategy chain
# --> 666             val = strategy_chain.run(i, temperature)
#     667             if val is not None:
#     668                 message.append(val)
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_dual_annealing.py in run(self, step, temperature)
#     288                 self.energy_state.current_location, j, temperature)
#     289             # Calling the objective function
# --> 290             e = self.func_wrapper.fun(x_visit)
#     291             if e < self.energy_state.current_energy:
#     292                 # We have got a better energy value
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_dual_annealing.py in fun(self, x)
#     371     def fun(self, x):
#     372         self.nfev += 1
# --> 373         return self.func(x, *self.args)
#     374
#     375
#
# ~/ascec/amcess/electronic_energy_2.py in energy(self, x)
#      88             mf.conv_tol_grad = 1e-10
#      89             mf.max_cycle = 200
# ---> 90         mf.kernel()
#      91         return mf.energy_tot()
#
# ~/.local/lib/python3.8/site-packages/pyscf/lib/misc.py in aliased_fn(self, *args, **kwargs)
#     634     fname = fn.__name__
#     635     def aliased_fn(self, *args, **kwargs):
# --> 636         return getattr(self, fname)(*args, **kwargs)
#     637
#     638     if alias_name is not None:
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in scf(self, dm0, **kwargs)
#    1646             self.converged, self.e_tot, \
#    1647                     self.mo_energy, self.mo_coeff, self.mo_occ = \
# -> 1648                     kernel(self, self.conv_tol, self.conv_tol_grad,
#    1649                            dm0=dm0, callback=self.callback,
#    1650                            conv_check=self.conv_check, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in kernel(mf, conv_tol, conv_tol_grad, dump_chk, dm0, callback, conv_check, **kwargs)
#     175         # attach mo_coeff and mo_occ to dm to improve DFT get_veff efficiency
#     176         dm = lib.tag_array(dm, mo_coeff=mo_coeff, mo_occ=mo_occ)
# --> 177         vhf = mf.get_veff(mol, dm, dm_last, vhf)
#     178         e_tot = mf.energy_tot(dm, h1e, vhf)
#     179
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in get_veff(self, mol, dm, dm_last, vhf_last, hermi)
#    1964         if dm is None: dm = self.make_rdm1()
#    1965         if self._eri is not None or not self.direct_scf:
# -> 1966             vj, vk = self.get_jk(mol, dm, hermi)
#    1967             vhf = vj - vk * .5
#    1968         else:
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in get_jk(self, mol, dm, hermi, with_j, with_k, omega)
#    1954             if self._eri is None:
#    1955                 self._eri = mol.intor('int2e', aosym='s8')
# -> 1956             vj, vk = dot_eri_dm(self._eri, dm, hermi, with_j, with_k)
#    1957         else:
#    1958             vj, vk = SCF.get_jk(self, mol, dm, hermi, with_j, with_k, omega)
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in dot_eri_dm(eri, dm, hermi, with_j, with_k)
#     716             vk = vk.reshape(dm.shape)
#     717     else:
# --> 718         vj, vk = _vhf.incore(eri, dm.real, hermi, with_j, with_k)
#     719         if dm.dtype == numpy.complex128:
#     720             vs = _vhf.incore(eri, dm.imag, 0, with_j, with_k)
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/_vhf.py in incore(eri, dms, hermi, with_j, with_k)
#     211         if with_j:
#     212             fvj = _fpointer('CVHFics8_tridm_vj')
# --> 213             tridms = lib.pack_tril(lib.hermi_sum(dms, axes=(0,2,1)))
#     214             idx = numpy.arange(nao)
#     215             tridms[:,idx*(idx+1)//2+idx] *= .5
#
# ~/.local/lib/python3.8/site-packages/pyscf/lib/numpy_helper.py in hermi_sum(a, axes, hermi, inplace, out)
#     661     else:
#     662         fn = _np_helper.NPzhermi_021_sum
# --> 663     fn(c_shape, a.ctypes.data_as(ctypes.c_void_p),
#     664        out.ctypes.data_as(ctypes.c_void_p), ctypes.c_int(hermi))
#     665     return out
#
# KeyboardInterrupt:

# %%
#If you want to find the local minima with the gaussian method, you can use the
#following function.

minima = LocalMinima(initial_cluster=w2).gaussian_optimize()
print(minima.fun)
# Out:
# converged SCF energy = -149.860410960842
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_28143/3859153914.py in <module>
#       2 #following function.
#       3
# ----> 4 minima = LocalMinima(initial_cluster=w2).gaussian_optimize()
#       5 print(minima.fun)
#
# ~/ascec/amcess/local_minima_2.py in gaussian_optimize(self)
#     221         """
#     222         energie = self.energy
# --> 223         minimo = solve_gaussian_processes(energie, bounds=self.bounds)
#     224         return minimo
#     225
#
# ~/ascec/amcess/gaussian_process.py in solve_gaussian_processes(func, bounds, args, seed, gp_params)
#     296         model, space, objective, acquisition, evaluator, initial_design
#     297     )
# --> 298     opt.run_optimization(
#     299         max_iter=gp_params["maxiter"], **run_optimization_args
#     300     )
#
# ~/.local/lib/python3.8/site-packages/GPyOpt/core/bo.py in run_optimization(self, max_iter, max_time, eps, context, verbosity, save_models_parameters, report_file, evaluations_file, models_file)
#     120         # --- Initial function evaluation and model fitting
#     121         if self.X is not None and self.Y is None:
# --> 122             self.Y, cost_values = self.objective.evaluate(self.X)
#     123             if self.cost.cost_type == 'evaluation_time':
#     124                 self.cost.update_cost_model(self.X, cost_values)
#
# ~/ascec/amcess/gaussian_process.py in evaluate(self, x)
#     104
#     105         if self.n_procs == 1:
# --> 106             f_evals, cost_evals = self._eval_func(x)
#     107         else:
#     108             try:
#
# ~/ascec/amcess/gaussian_process.py in _eval_func(self, x)
#     133             st_time = time.time()
#     134             # rlt = self.func(np.atleast_2d(x[i]), self.args)
# --> 135             rlt = self.func(np.ravel(x[i]), *self.args)
#     136             f_evals = np.vstack([f_evals, rlt])
#     137             cost_evals += [time.time() - st_time]
#
# ~/ascec/amcess/electronic_energy_2.py in energy(self, x)
#      88             mf.conv_tol_grad = 1e-10
#      89             mf.max_cycle = 200
# ---> 90         mf.kernel()
#      91         return mf.energy_tot()
#
# ~/.local/lib/python3.8/site-packages/pyscf/lib/misc.py in aliased_fn(self, *args, **kwargs)
#     634     fname = fn.__name__
#     635     def aliased_fn(self, *args, **kwargs):
# --> 636         return getattr(self, fname)(*args, **kwargs)
#     637
#     638     if alias_name is not None:
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in scf(self, dm0, **kwargs)
#    1646             self.converged, self.e_tot, \
#    1647                     self.mo_energy, self.mo_coeff, self.mo_occ = \
# -> 1648                     kernel(self, self.conv_tol, self.conv_tol_grad,
#    1649                            dm0=dm0, callback=self.callback,
#    1650                            conv_check=self.conv_check, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in kernel(mf, conv_tol, conv_tol_grad, dump_chk, dm0, callback, conv_check, **kwargs)
#     175         # attach mo_coeff and mo_occ to dm to improve DFT get_veff efficiency
#     176         dm = lib.tag_array(dm, mo_coeff=mo_coeff, mo_occ=mo_occ)
# --> 177         vhf = mf.get_veff(mol, dm, dm_last, vhf)
#     178         e_tot = mf.energy_tot(dm, h1e, vhf)
#     179
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in get_veff(self, mol, dm, dm_last, vhf_last, hermi)
#    1964         if dm is None: dm = self.make_rdm1()
#    1965         if self._eri is not None or not self.direct_scf:
# -> 1966             vj, vk = self.get_jk(mol, dm, hermi)
#    1967             vhf = vj - vk * .5
#    1968         else:
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in get_jk(self, mol, dm, hermi, with_j, with_k, omega)
#    1954             if self._eri is None:
#    1955                 self._eri = mol.intor('int2e', aosym='s8')
# -> 1956             vj, vk = dot_eri_dm(self._eri, dm, hermi, with_j, with_k)
#    1957         else:
#    1958             vj, vk = SCF.get_jk(self, mol, dm, hermi, with_j, with_k, omega)
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/hf.py in dot_eri_dm(eri, dm, hermi, with_j, with_k)
#     716             vk = vk.reshape(dm.shape)
#     717     else:
# --> 718         vj, vk = _vhf.incore(eri, dm.real, hermi, with_j, with_k)
#     719         if dm.dtype == numpy.complex128:
#     720             vs = _vhf.incore(eri, dm.imag, 0, with_j, with_k)
#
# ~/.local/lib/python3.8/site-packages/pyscf/scf/_vhf.py in incore(eri, dms, hermi, with_j, with_k)
#     211         if with_j:
#     212             fvj = _fpointer('CVHFics8_tridm_vj')
# --> 213             tridms = lib.pack_tril(lib.hermi_sum(dms, axes=(0,2,1)))
#     214             idx = numpy.arange(nao)
#     215             tridms[:,idx*(idx+1)//2+idx] *= .5
#
# ~/.local/lib/python3.8/site-packages/pyscf/lib/numpy_helper.py in hermi_sum(a, axes, hermi, inplace, out)
#     661     else:
#     662         fn = _np_helper.NPzhermi_021_sum
# --> 663     fn(c_shape, a.ctypes.data_as(ctypes.c_void_p),
#     664        out.ctypes.data_as(ctypes.c_void_p), ctypes.c_int(hermi))
#     665     return out
#
# KeyboardInterrupt:
